# %%
import pandas as pd
import numpy as np

# %%
AA=pd.read_csv("data/AA.csv",index_col=0)
data=pd.read_csv("data/data_2.csv",index_col=0)
data2=pd.read_csv("data/data2_2.csv",index_col=0)
display(AA,data,data2)
# Out:
# d:\Anaconda\envs\py37\lib\site-packages\numpy\lib\arraysetops.py:580: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                 id         id2        AA
# 0         87702431    87656949  0.149936
# 1         87702431    87658277  0.402430
# 2         87702431    87660311  0.159273
# 3         87702431    87661375  0.480898
# 4         87702431    87661377  3.669469
# ...            ...         ...       ...
# 1204717  546087303   728537983  0.360674
# 1204718  546087303   739378733  0.360674
# 1204719  546087303   953045623  0.360674
# 1204720  546087303  1507513985  0.360674
# 1204721  671476929   608364631  1.442695
#
# [1204722 rows x 3 columns]
#              userID        ffID  cn  targetUser_x fName_x  gender_x  \
# index
# 0          87702431    87656949   1             1       王       1.0
# 1          87808217    87656949  10             1       张       1.0
# ...

# %%
data=pd.merge(data,AA,how="left",left_on=["userID","ffID"],right_on=["id","id2"])
# Out:
#              userID        ffID  cn  targetUser_x fName_x  gender_x  \
# 0          87702431    87656949   1             1       王       1.0
# 1          87808217    87656949  10             1       张       1.0
# 2         139840069    87656949   1             1       叶       0.0
# 3         150023465    87656949   1             1       沈       1.0
# 4         155712967    87656949   1             1       吕       1.0
# ...             ...         ...  ..           ...     ...       ...
# 1158708  3195846773  1516349333  18             1       袁       1.0
# 1158709  3195846773  3290351601  24             1       袁       1.0
# 1158710  3195846773  3340133093  18             1       袁       1.0
# 1158711  3195846773  3405622929  15             1       袁       1.0
# 1158712  3195846773  4097459911  20             1       袁       1.0
#
#          starUser_x  mobileUser_x homeProvince_x homeCity_x  ...       HPI  \
# ...

# %%
data=data.drop(["id","id2"],axis=1)
data
# Out:
#              userID        ffID  cn  targetUser_x fName_x  gender_x  \
# 0          87702431    87656949   1             1       王       1.0
# 1          87808217    87656949  10             1       张       1.0
# 2         139840069    87656949   1             1       叶       0.0
# 3         150023465    87656949   1             1       沈       1.0
# 4         155712967    87656949   1             1       吕       1.0
# ...             ...         ...  ..           ...     ...       ...
# 1158708  3195846773  1516349333  18             1       袁       1.0
# 1158709  3195846773  3290351601  24             1       袁       1.0
# 1158710  3195846773  3340133093  18             1       袁       1.0
# 1158711  3195846773  3405622929  15             1       袁       1.0
# 1158712  3195846773  4097459911  20             1       袁       1.0
#
#          starUser_x  mobileUser_x homeProvince_x homeCity_x  ...  timeline_y  \
# ...

# %%
data.to_csv("data/data_2.csv")

# %%
data2=pd.merge(data2,AA,how="left",left_on=["userID","ffID"],right_on=["id","id2"])
print(np.any(np.isnan(data2.AA)))
data2=data2.drop(["id","id2"],axis=1)
# Out:
# False

# %%
data2.to_csv("data/data2_2.csv")

# %%
clf=lgbm.Booster(model_file="data/booster_.pt")
clf.params
# Out:
# {}
