# %% [markdown]
#  ## 读取文件

# %%
from 处理文件 import Read
import numpy as np
import pandas as pd
# 读取的路径
read_file="../data/Beijing-2022-06-21/"
# 整合出来的csv写入的路径
write_file="Beijing-result-2022-06-21.csv"

# %%
Beijing=Read(read_file)
# Out:
# 正在读取 ../data/Beijing-2022-06-21/
# 读取结束....

# %%
reviews=Beijing["reviews_2"]
print("reviews.head():")
print(reviews.head())
# Out:
# reviews.head():
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     2797791  12474674  2014-05-03     14302219         Evita
# 1     2797791  13498309  2014-05-28      5012139       Michael
# 2     2797791  13716163  2014-06-02      9746859           Tim
# 3     2797791  29367253  2015-04-06       460773           Amy
# 4     2797791  31140426  2015-05-02      3531093    Christophe
#
#                                             comments
# 0  We spent a weekend at Andrew's (Website hidden...
# 1  The reservation was canceled 4 days before arr...
# 2  It was an epic weekend thanks to Andrew and hi...
# 3  Nine of us had a very relaxing weekend getaway...
# 4  The house was exactly as described and on pict...

# %%
calender=Beijing["calender"]
print("calender.head():")
print(calender.head())
# Out:
# calender.head():
#    listing_id        date available      price adjusted_price  minimum_nights  \
# 0     2797791  2022-06-21         t  $1,800.00      $1,800.00               1
# 1     2797791  2022-06-22         t  $1,800.00      $1,800.00               1
# 2     2797791  2022-06-23         t  $1,800.00      $1,800.00               1
# 3     2797791  2022-06-24         t  $2,500.00      $2,500.00               1
# 4     2797791  2022-06-25         t  $2,500.00      $2,500.00               1
#
#    maximum_nights
# 0              14
# 1              14
# 2              14
# 3              14
# 4              14

# %%
listings=Beijing["listings"]
print("listings.head():")
print(listings.head())
# Out:
# listings.head():
#         id                                               name   host_id  \
# 0  2797791                          Beijing Great Wall Escape  14311129
# 1  4990531  Monthly Discounted- Orchid's Residence Expansi...  25729513
# 2  6207089                               雍和宫地铁附近崇文门东单南二环精装双床房  32187257
# 3  6223892                  北京家诚-方庄蒲黄榆南站地铁情侣观景房，舒适大床，可做饭，新中式风  32187257
# 4  6232044                                同仁协和医院东单五号线地铁旁家庭双床房  32187257
#
#   host_name  neighbourhood_group  neighbourhood  latitude  longitude  \
# 0    Andrew                  NaN  怀柔区 / Huairou  40.47329  116.54511
# 1      Joel                  NaN            东城区  39.94193  116.39843
# 2       May                  NaN  丰台区 / Fengtai  39.86475  116.42335
# 3       May                  NaN  丰台区 / Fengtai  39.86503  116.42774
# 4       May                  NaN  丰台区 / Fengtai  39.86369  116.42801
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   2000               1                 56  2021-07-28
# 1  Entire home/apt   1610              29                 20  2020-08-21
# 2  Entire home/apt    388               1                  7  2022-04-18
# 3  Entire home/apt    358               1                  8  2022-04-22
# 4  Entire home/apt    498               1                  1  2021-12-25
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.57                               1                38
# 1               0.22                              10                 0
# 2               0.12                               9                38
# 3               0.23                               9                38
# 4               0.17                               9                38
#
#    number_of_reviews_ltm  license
# 0                      1      NaN
# 1                      0      NaN
# 2                      5      NaN
# 3                      7      NaN
# 4                      1      NaN

# %%
listings_2=Beijing["listings_2"]
print("listings_2.head():")
print(listings_2.head())
# Out:
# listings_2.head():
#         id                           listing_url       scrape_id last_scraped  \
# 0  2797791  https://www.airbnb.com/rooms/2797791  20220621060517   2022-06-21
# 1  4990531  https://www.airbnb.com/rooms/4990531  20220621060517   2022-06-21
# 2  6207089  https://www.airbnb.com/rooms/6207089  20220621060517   2022-06-21
# 3  6223892  https://www.airbnb.com/rooms/6223892  20220621060517   2022-06-21
# 4  6232044  https://www.airbnb.com/rooms/6232044  20220621060517   2022-06-21
#
#                                                 name  \
# 0                          Beijing Great Wall Escape
# 1  Monthly Discounted- Orchid's Residence Expansi...
# 2                               雍和宫地铁附近崇文门东单南二环精装双床房
# 3                  北京家诚-方庄蒲黄榆南站地铁情侣观景房，舒适大床，可做饭，新中式风
# 4                                同仁协和医院东单五号线地铁旁家庭双床房
#
#                                          description  \
# 0  A perfect escape only 2 hours away from Beijin...
# 1  Begin the day in the tiled rain shower and wit...
# 2  位于北京市丰台区方庄物美大卖场旁（地铁5号线蒲黄榆站楼上）。交通非常便利：距离南二环玉蜓桥南...
# 3  房间位于地铁五号线蒲黄榆站楼上，楼下是方庄物美大卖场，房间设施免费使用，35寸超大液晶电视，...
# 4  位于北京市丰台区方庄物美大卖场旁（地铁5号线蒲黄榆站楼上）。交通非常便利：距离南二环玉蜓桥南...
#
#                                neighborhood_overview  \
# 0  Located in a small village at the base of the ...
# 1  The neighborhood is very safe and full of loca...
# 2  公寓北部是龙潭湖公园，西北是天坛公园、北京游乐场、北京教学植物园、北京国际网球中心、南面是中...
# 3          美食：海底捞火锅方庄店、全聚德烤鸭店，方庄时代广场<br />娱乐：博纳国际电影院
# 4  北部是龙潭湖公园，西北是天坛公园、北京游乐场、北京教学植物园、北京国际网球中心、南面是中央音...
#
#                                          picture_url   host_id  \
# 0  https://a0.muscache.com/pictures/da7d00b7-37f0...  14311129
# 1  https://a0.muscache.com/pictures/ebd3ed91-02e2...  25729513
# 2  https://a0.muscache.com/pictures/83597610/e003...  32187257
# 3  https://a0.muscache.com/pictures/miso/Hosting-...  32187257
# 4  https://a0.muscache.com/pictures/miso/Hosting-...  32187257
#
#                                      host_url  ...  \
# 0  https://www.airbnb.com/users/show/14311129  ...
# 1  https://www.airbnb.com/users/show/25729513  ...
# 2  https://www.airbnb.com/users/show/32187257  ...
# 3  https://www.airbnb.com/users/show/32187257  ...
# 4  https://www.airbnb.com/users/show/32187257  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.92                   4.91                4.30
# 1                        4.88                   4.88                4.76
# 2                        5.00                   5.00                5.00
# 3                        5.00                   5.00                5.00
# 4                        5.00                   5.00                5.00
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                f                             10
# 2     NaN                t                              9
# 3     NaN                t                              9
# 4     NaN                t                              9
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           6
# 2                                           9
# 3                                           9
# 4                                           9
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            4
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              0.57
# 1                                           0              0.22
# 2                                           0              0.12
# 3                                           0              0.23
# 4                                           0              0.17
#
# [5 rows x 74 columns]

# %% [markdown]
#  * 结论一
#      * 经过上面一顿操作，发现目前对我们有用的表格好像是listings,reviews,listings_2
#      * 关键的主键有两种，一种是用户id,一种是房源的id
#      * 聚合时，应该用listings,reviews的模式来聚合，因为我们关注的是房源定价的高低。
#      * 进一步看看

# %% [markdown]
#  ## 首先应该把reviews中的文本进行充分之挖掘，得到好评、差评的数据

# %%
import textblob
from snownlp import SnowNLP

# %% [markdown]
#  * 情绪可以考虑不只是描述其正负面，可以考虑赋予其值。

# %% [markdown]
#  ### 使用apply函数返回各个评论的情绪

# %%
def Process_review(reviews_2:str)->str:
    """对评论数据进行操作，计算其sentiment,返回情绪值"""
    if reviews_2 is np.nan or reviews_2 is None:
        return 0
    temp=reviews_2
    blob=textblob.TextBlob(temp)
    s=SnowNLP(temp)
    return s.sentiments*2-1+blob.sentiment.polarity*2

# %%
print("正在对reviews进行情绪评估，可能需要若干分钟时间...")
reviews.loc[:,"sentiment"]=reviews.loc[:,"comments"].apply(Process_review)
# Out:
# 正在对reviews进行情绪评估，可能需要若干分钟时间...

# %% [markdown]
#  ## 分别探索各个数据的模式，挖掘可能的信息

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
def describe(data:pd.DataFrame):
    """给出基本的数据描述，包括是否含有缺失值等"""
    print("="*70)
    print("表格形状：",data.shape)
    temp_1=pd.Series([pd.unique(data.loc[:,i]).shape[0] for i in data.columns],index=data.columns,name="独立元素个数")
    temp_3=temp_1/data.shape[0];temp_3.name="独立元素比例"
    temp=np.sum(data.isna())
    temp.index=data.columns
    temp.name="缺失值个数"
    temp_2=pd.merge(left=temp_1,right=temp,how="inner",left_index=True,right_index=True)
    temp_2=pd.merge(left=temp_2,right=temp_3,left_index=True,right_index=True)
    print("结果：\n",temp_2.to_string())
    if np.any(temp)!=0:
        data_na=data.loc[np.any(data.isna(),axis=1),:].isna()
        plt.figure(figsize=(5,5))
        sns.heatmap(data_na)
        plt.show()
    print("="*70)

# %% [markdown]
#  * reviews结果说明：
#      * sentiment: 按照listing_id进行聚合与别的listing进行合并

# %% [markdown]
#  * calender是按照未来365天listing的日历进行排列的
#      * 主键：listing_id,date
#      * available：是否有房。
#      * price,adjusted_price:adjusted_price应该是根据季度进行的正儿八经的价格，和是否有房有着很大的关系，应该分时间、listing_id进一步探索
#      * minimum_nights,maximum_nights和房子的价格有很大关系。
#  * 总体来说，应该按照calender进行计算，把如下公式作为房东$x$满意收益（在4.典型房东应用部分会用到）：
#      $$Adjusted\_price_x \cdot not_available_x-\frac{\sum_{i}{Adjust\_price_{i,j}\cdot \mathbf{1}}}{\sum_{i}1}$$
#      其中$i$是这个地区中的所有房子,$j$是365天每天的价格。

# %% [markdown]
#  * 缺失元素之间有很强的关联

# %% [markdown]
#  * listings_2应该是主要的参数来源
#  * listings表是listings_2表的子集

# %% [markdown]
#  ## 数据清洗-数据合并-数据再清洗

# %%
# 把reviews进行聚合，主要是进行情感聚合
group_reviews=reviews.groupby("listing_id",as_index=False)["sentiment"].mean()
print("对评论数据计算情绪值结束，每个房源的平均情绪展示前五条：")
print(group_reviews.head())
# Out:
# 对评论数据计算情绪值结束，每个房源的平均情绪展示前五条：
#    listing_id  sentiment
# 0     2797791  -0.089427
# 1     4990531  -0.214929
# 2     6207089   0.717351
# 3     6223892   0.467677
# 4     6232044   0.477768

# %%
def To_number(str_price):
    """把price价格去掉$,变成number"""
    if type(str_price)==float:
        return str_price
    while str_price.find("$")!=-1:
        str_price=str_price[:str_price.find("$")]+str_price[str_price.find("$")+1:]
    while str_price.find(",")!=-1:
        str_price=str_price[:str_price.find(",")]+str_price[str_price.find(",")+1:]
    return float(str_price)
# 对calender进行清洗
calender.loc[calender.loc[:,"available"]=="f","notavailable"]=1
calender.loc[calender.loc[:,"available"]=="t","notavailable"]=0
calender.loc[:,"adjusted_price"]=calender.loc[:,"adjusted_price"].apply(To_number)
def compute_calender(data:pd.DataFrame):
    """对calender进行最后的计算，返回notavaiable比率和相应adjusted_price"""
    # 先把这里面全是notavailable的给删掉，返回空值
    if np.all(data.notavailable==1):
        print("在calender中删掉了一些异常数据，异常数据listing_id为:",pd.unique(data.listing_id))
        return None
    temp=data.groupby("adjusted_price",as_index=False)["notavailable"].mean()
    temp["listing_id"]=pd.unique(data["listing_id"])[0]
    return temp

print("正在聚合calender的数据...")
group_calender=calender.groupby("listing_id",as_index=False).apply(compute_calender)
group_calender.index=[i for i in range(0,group_calender.shape[0])]
print("聚合完成，展示如下：")
print(group_calender.head())
# Out:
# 正在聚合calender的数据...
# 在calender中删掉了一些异常数据，异常数据listing_id为: [4990531]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [6243409]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [6801565]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [7151567]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [7683294]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [11667483]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [13123730]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [13341378]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [13379195]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [13475791]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [15116410]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [15316755]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [15524594]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [15721690]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [16024957]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [16241759]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [17685902]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [18182586]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [18534340]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [18727955]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [18801952]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [19089155]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [19262691]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [19509125]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [19830773]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20213067]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20310816]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20313678]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20365318]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20443515]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20547206]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20807656]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20869354]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [20985061]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21034087]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21060190]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21074018]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21074761]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21105096]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21127500]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21166385]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21178237]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21210087]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21244043]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21254964]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21585601]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [21754937]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [22067494]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [22454390]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [22934907]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [23136915]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [23157712]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [23753247]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [23874929]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24293025]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24320401]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24320987]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24324205]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24339056]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24412754]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24478848]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24718160]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24790710]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24816522]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [24935249]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25045320]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25112244]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25124252]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25124857]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25176213]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25215060]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25330079]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25394492]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25549848]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25636291]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25661530]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25793928]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25987784]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [25997400]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26109555]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26212745]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26375055]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26444202]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26445345]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26481541]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26611572]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26612259]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26612396]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26784171]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [26971879]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [27107635]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [27173327]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [27513204]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [27561770]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [27765927]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [27789441]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [27825149]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28037577]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28142232]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28147566]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28148426]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28152914]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28200893]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28302716]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28438566]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28548211]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28602318]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28612457]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28709972]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28793202]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28832892]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28863523]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28864004]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28870537]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28871040]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28871284]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28872634]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28873117]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28876087]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28903923]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28909832]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28919782]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28920473]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28941631]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28943249]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28943346]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28943421]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28943467]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28949172]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [28999408]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29001880]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29041628]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29083550]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29110570]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29494914]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29554278]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29583182]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29623211]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29801836]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [29818600]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [30058081]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [30094446]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [30183660]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [30342281]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [30406061]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [30541844]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [30770699]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31005446]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31052438]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31186173]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31500631]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31525938]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31529207]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31617121]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31814820]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31875495]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31888549]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31888830]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31889991]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [31890417]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32047660]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32047879]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32051893]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32075918]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32090977]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32091179]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32091277]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32155466]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32407625]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32577997]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32845646]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [32950369]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33185054]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33347174]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33357406]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33409383]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33409593]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33410221]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33437058]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33464135]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33482286]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33535937]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33619658]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33623425]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33625451]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33663578]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33690453]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33693750]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33697959]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33720239]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33824068]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33846505]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33865938]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33887909]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33947276]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [33955020]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34029808]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34065850]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34066470]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34066744]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34067534]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34095805]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34096882]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34097303]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34156243]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34156293]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34158354]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34197913]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34237353]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34259345]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34262933]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34263104]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34264024]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34289484]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34290018]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34291527]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34292289]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34292744]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34344894]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34348193]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34410557]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34427261]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34428732]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34431219]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34432802]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34464423]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34494240]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34494254]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34518057]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34527055]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34545247]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34551637]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34606514]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34814193]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34831975]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34867504]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34886533]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34912014]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34914514]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34946194]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34953243]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [34981779]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35043228]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35058803]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35066495]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35097822]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35100355]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35106231]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35134189]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35240611]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35271110]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35271335]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35271675]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35322911]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35359840]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35360620]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35361037]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35361246]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35361606]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35361749]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35386156]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35391339]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35396191]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35436207]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35445257]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35474017]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35523256]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35546472]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35549555]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35591116]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35595085]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35621275]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35621558]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35636767]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35665920]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35671042]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35725710]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35726715]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35745412]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35755913]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35755990]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35769045]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35769461]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35808410]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35828010]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35844573]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35857089]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35878740]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35891154]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35914357]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [35984762]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36011177]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36039272]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36082281]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36124697]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36187195]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36198689]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36211399]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36217310]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36241542]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36242626]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36244661]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36249840]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36280732]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36319653]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36330873]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36376876]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36393820]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36404367]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36459877]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36472727]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36476606]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36495665]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36504932]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36550243]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36580771]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36590488]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36614060]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36614961]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36626461]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36626749]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36678049]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36682717]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36707680]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36719241]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36720118]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36747154]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36749102]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36755962]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36807373]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36812305]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36831684]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36831922]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36850230]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36850932]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36851077]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36851224]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36918232]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36922115]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [36927800]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37041896]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37046432]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37047186]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37075186]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37079173]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37130880]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37260400]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37329166]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37366244]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37366665]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37563279]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37568942]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37664466]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37699270]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37732368]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37733466]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37763771]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37793211]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37817635]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37829655]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37844255]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37918063]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [37961555]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38010693]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38027995]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38075475]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38134993]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38165105]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38197455]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38278579]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38390523]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38392594]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38402739]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38417932]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38423708]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38448306]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38532280]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38553471]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38567483]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38568764]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38568963]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38570015]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38615143]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38616173]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38658321]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38664154]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38676120]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38688542]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38714278]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38718505]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38760656]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38862835]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38884371]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38915747]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38916911]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38946200]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38959020]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38959149]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38967443]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38972598]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38985135]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [38993419]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39010432]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39012965]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39016415]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39069618]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39097766]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39123209]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39123556]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39123813]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39163957]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39207907]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39285406]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39285453]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39285456]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39285460]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39285463]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39312016]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39314036]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39495530]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39495696]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39524235]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39539263]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39569516]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39572068]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39573110]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39573923]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39574606]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39574812]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39575774]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39576163]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39594348]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39759906]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39765223]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39906780]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [39980474]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40080795]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40140730]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40169683]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40182349]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40183285]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40185558]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40187605]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40189422]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40213941]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40240113]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40240324]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40267695]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40269893]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40355921]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40356136]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40430735]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40612739]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40670331]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40680911]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40745061]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40746958]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40747069]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40760722]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40902803]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40904196]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40953084]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40980381]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [40997515]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41110414]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41137047]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41137287]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41142715]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41167024]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41167316]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41241754]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41352367]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41355371]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41372154]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41509601]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41511392]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41534703]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41552225]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41600485]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41600825]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41608082]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41623920]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41674254]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41675104]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [41786957]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42123205]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42127159]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42145540]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42208784]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42208860]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42211701]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42211897]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42211952]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42415663]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42745745]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42846395]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42846992]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42846993]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42846995]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42846997]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42847000]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42847102]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42850196]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42850197]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42850199]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42850204]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42850205]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42850789]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [42871572]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43047598]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43062965]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43072383]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43231028]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43296177]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43359905]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43548356]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43558313]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43558726]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43558861]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43558945]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43560103]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43560119]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43630363]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43631032]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43646248]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43651882]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43651957]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43652081]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43652083]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43657248]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43657890]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43703981]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43722085]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43771298]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [43837976]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44028989]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44112551]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44146916]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44197198]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44237846]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44245576]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44284090]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44316937]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44407617]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44433225]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44457750]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44467758]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44468076]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44473724]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44508988]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44560663]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44624595]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44648051]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44675176]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44828361]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44923987]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [44924367]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45059484]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45105053]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45182205]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45194550]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45209738]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45232088]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45251283]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45268895]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45279556]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45319342]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45320585]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45320671]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45320974]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45321091]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45321187]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45370546]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45414503]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45446083]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45446414]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45458071]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45518426]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45521478]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45521634]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45536982]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45599866]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45621866]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45624873]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45744427]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45831228]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45854020]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45931813]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45932016]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45932145]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45961707]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45983330]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45988719]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45988720]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [45989254]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46094674]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46135724]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46166595]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46484314]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46552021]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46698463]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46751214]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46754708]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46785378]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [46996384]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47002417]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47014034]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47020876]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47141754]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47212148]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47229789]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47362869]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47435629]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47498523]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47498618]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47498689]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47498849]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47499196]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47708018]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47774918]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47774920]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47849083]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47865535]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [47948091]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48098476]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48098552]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48564678]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48684410]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48780556]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48841737]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48889328]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48897705]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [48951023]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49044365]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49088553]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49089211]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49089306]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49089565]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49100392]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49102076]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49107825]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49117836]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49134406]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49138803]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49148524]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49182443]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49261929]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49262233]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49262604]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49263457]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49276946]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49324453]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49333746]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49347075]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49376482]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49453200]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49486756]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49496810]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49526146]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49533481]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49583121]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49638641]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49657985]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49661801]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49682883]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49715342]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49724013]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49749724]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49760775]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49761302]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49888742]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49950290]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [49990049]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50000074]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50000078]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50140476]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50142729]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50143042]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50200545]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50224256]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50235148]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50239146]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50252249]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50269796]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50270014]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50278728]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50292112]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50294057]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50365442]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50402614]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50405026]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50423029]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50423329]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50423405]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50475134]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50498216]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50508947]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50612107]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50654811]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50672443]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50708723]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50715090]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50731910]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50736711]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50777242]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50800952]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50804809]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50856044]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50857292]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [50877485]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51091490]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51218335]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51219268]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51219598]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51219703]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51273162]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51434438]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51435955]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51436370]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51436708]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51436836]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51437988]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51438257]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51457146]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51477495]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51477869]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51478218]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51478463]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51550824]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51550931]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51606149]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51607322]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51642678]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51662953]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51716517]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51737926]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51829353]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51829965]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51852745]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [51949427]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52048413]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52095770]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52289668]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52433705]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52464091]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52695859]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52696796]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52725425]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52784163]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52845573]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52846957]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52847337]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52864541]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [52864650]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53097674]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53136872]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53137999]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53138878]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53138917]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53138955]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53139188]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53139527]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53139536]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53139737]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53139738]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53140385]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53140456]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53140578]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53140712]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53140723]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53140737]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53140925]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53175924]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53191579]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53266819]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53404677]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53483665]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53485048]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53485269]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53485372]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53485485]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53485565]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53485782]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53491265]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53502540]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53502766]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53551326]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53577303]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53577435]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53577512]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53619986]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53630617]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53633067]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53633257]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53633603]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53633730]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53634073]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53860042]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53860044]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53860048]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53860050]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53861593]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53861604]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53861615]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53897505]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53897515]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53897528]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [53925910]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54058942]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54096129]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54190696]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54234472]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54234619]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54234709]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54234800]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54234858]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [54234917]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [541476134690733524]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [547289408431898957]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [561969306105685158]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [562503835416313366]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [562598597483356394]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [562664241932102138]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [563272391572799232]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [571520965206047981]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [572304482590345246]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [572309445559384417]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [572316306255734737]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [572320889752948362]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [572325898781125125]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [572331243527612901]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [572336481158668987]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [575499980876809442]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [575522328766956784]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [575522387657127163]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [575522772427296882]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [579384650235073771]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [580162034948781042]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [590171427899476978]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [602688958228585457]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [624267508439204253]
# 在calender中删掉了一些异常数据，异常数据listing_id为: [625068980236647652]
# 聚合完成，展示如下：
#    adjusted_price  notavailable  listing_id
# 0          1800.0      0.892720     2797791
# 1          2500.0      0.903846     2797791
# 2           388.0      0.000000     6207089
# 3           398.0      1.000000     6207089
# 4           488.0      1.000000     6207089

# %%
# 清洗listings_2，并确定入列元素
listings_2["is_description"]=1
listings_2.loc[listings_2.loc[:,"description"].isna(),"is_description"]=0
listings_2["is_neighborhood_overview"]=1
listings_2.loc[listings_2.loc[:,"neighborhood_overview"].isna(),"is_neighborhood_overview"]=0
listings_2["is_host_about"]=1
listings_2.loc[listings_2.loc[:,"host_about"].isna(),"is_host_about"]=0
#删除host_response_time,host_response_rate的缺失数据
listings_2=listings_2.loc[listings_2.loc[:,"host_response_time"].notna(),:]
listings_2=listings_2.loc[listings_2.loc[:,"host_response_rate"].notna(),:]
listings_2=listings_2.loc[listings_2.loc[:,"host_acceptance_rate"].notna(),:]
#reviews_per_month缺失值到时候直接置为0
listings_2.loc[listings_2.loc[:,"reviews_per_month"].isna(),"reviews_per_month"]=0

# %%
# 确定所有进入数据合并的列
group_calender_column=["listing_id","adjusted_price","notavailable"]
group_reviews_column=["listing_id","sentiment"]
listings_2_column=["id","is_description","is_neighborhood_overview","is_host_about",'host_since',"host_response_time",
                  'host_response_rate', 'host_acceptance_rate','host_is_superhost',"host_listings_count",
                 "host_total_listings_count","host_verifications","host_has_profile_pic",'host_identity_verified',
                   'neighbourhood_cleansed','latitude','longitude','property_type', 'room_type', 'accommodates','bathrooms_text',
                   'bedrooms', 'beds','minimum_nights', 'maximum_nights','number_of_reviews_ltm', 'number_of_reviews_l30d',
                 'review_scores_rating', 'review_scores_accuracy','review_scores_cleanliness', 'review_scores_checkin',
       'review_scores_communication', 'review_scores_location','review_scores_value', 'instant_bookable', 'reviews_per_month']

# %%
print("正在整合列表...")
result=pd.merge(group_calender.loc[:,group_calender_column],group_reviews.loc[:,group_reviews_column],how="left",left_on=["listing_id"],right_on=["listing_id"])
result=pd.merge(result,listings_2.loc[:,listings_2_column],how="left",left_on=["listing_id"],right_on=["id"])
result=result.loc[:,[i for i in result.columns if i!="id"]]
print("整合完成...")
print(result.head())
# Out:
# 正在整合列表...
# 整合完成...
#    listing_id  adjusted_price  notavailable  sentiment  is_description  \
# 0     2797791          1800.0      0.892720  -0.089427             1.0
# 1     2797791          2500.0      0.903846  -0.089427             1.0
# 2     6207089           388.0      0.000000   0.717351             1.0
# 3     6207089           398.0      1.000000   0.717351             1.0
# 4     6207089           488.0      1.000000   0.717351             1.0
#
#    is_neighborhood_overview  is_host_about  host_since host_response_time  \
# 0                       1.0            1.0  2014-04-15       within a day
# 1                       1.0            1.0  2014-04-15       within a day
# 2                       1.0            1.0  2015-04-29     within an hour
# 3                       1.0            1.0  2015-04-29     within an hour
# 4                       1.0            1.0  2015-04-29     within an hour
#
#   host_response_rate  ... number_of_reviews_l30d review_scores_rating  \
# 0               100%  ...                    0.0                 4.63
# 1               100%  ...                    0.0                 4.63
# 2               100%  ...                    0.0                 5.00
# 3               100%  ...                    0.0                 5.00
# 4               100%  ...                    0.0                 5.00
#
#    review_scores_accuracy  review_scores_cleanliness review_scores_checkin  \
# 0                    4.72                       4.24                  4.89
# 1                    4.72                       4.24                  4.89
# 2                    5.00                       5.00                  5.00
# 3                    5.00                       5.00                  5.00
# 4                    5.00                       5.00                  5.00
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.92                   4.91                 4.3
# 1                        4.92                   4.91                 4.3
# 2                        5.00                   5.00                 5.0
# 3                        5.00                   5.00                 5.0
# 4                        5.00                   5.00                 5.0
#
#    instant_bookable  reviews_per_month
# 0                 f               0.57
# 1                 f               0.57
# 2                 t               0.12
# 3                 t               0.12
# 4                 t               0.12
#
# [5 rows x 39 columns]

# %%
result=result.loc[result.loc[:,"is_description"].notna(),:]
result.loc[result.loc[:,"sentiment"].isna(),"sentiment"]=0

# %%
# bathrooms 按照个数来处理
def Process_bathrooms(text:str)->float:
    """处理厕所数量"""
    if text is None or text is np.nan:
        return np.nan
    if type(text)==str and "baths" in text:
        return float(text.split()[0])
    elif type(text)==str and text=="1 bath" or "1 private bath" or "1 shared bath":
        return float(1)
    elif type(text)==str and text=="Half-bath" or text=="Private half-bath" or text=="Shared half-bath":
        return float(0.5)
    elif text==0 or text=="0":
        return float(0)
    else:
        return np.nan

result.loc[:,"bathrooms"]=result.loc[:,"bathrooms_text"].apply(Process_bathrooms)
result=result.drop("bathrooms_text",axis=1)

# %%
def as_type(name):
    """把一些列变成float形式"""
    result.loc[:,name]=result.loc[:,name].astype("float")

l=["adjusted_price","notavailable","sentiment","is_description","is_neighborhood_overview","is_host_about"]
for i in l:
    as_type(i)

# 把str类型的时间变成float形式
def as_time(time):
    a=pd.Timestamp(listings_2.loc[1,"last_scraped"])-pd.Timestamp(time)
    return float(a.to_numpy()/10**9/3600/24)    
result.loc[:,"host_time"]=result.loc[:,"host_since"].apply(as_time)
result=result.drop("host_since",axis=1)

# %%
# 百分数变浮点数
def change_to_float(text:str):
    """把百分数转换为浮点数"""
    if text is np.nan or text is None:
        return text
    elif type(text)!=str:
        return text
    else:
        return float(text.strip("%"))/100

result.loc[:,"host_response_rate"]=result.loc[:,"host_response_rate"].apply(change_to_float)
result.loc[:,"host_acceptance_rate"]=result.loc[:,"host_acceptance_rate"].apply(change_to_float)
result.loc[result.loc[:,"host_is_superhost"]=="f","host_is_superhost"]=0
result.loc[result.loc[:,"host_is_superhost"]=="t","host_is_superhost"]=1
result.loc[result.loc[:,"instant_bookable"]=="f","instant_bookable"]=0
result.loc[result.loc[:,"instant_bookable"]=="t","instant_bookable"]=1
result.loc[result.loc[:,"host_has_profile_pic"]=="t","host_has_profile_pic"]=1
result.loc[result.loc[:,"host_has_profile_pic"]=="f","host_has_profile_pic"]=0
result.loc[result.loc[:,"host_identity_verified"]=="t","host_identity_verified"]=1
result.loc[result.loc[:,"host_identity_verified"]=="f","host_identity_verified"]=0

# %%
def Strip_verifications(text:str):
    """把verifications里面的文本长度存储起来"""
    if type(text)!=str:
        return text
    elif text[0]=="[" and text[-1]=="]":
        return len(list(eval(text)))
    else :
        return 0
result.loc[:,"host_verifications"]=result.loc[:,"host_verifications"].apply(Strip_verifications)

# %%
# 把不是float的全部转换成float
for i in result.columns:
    if type(result.loc[0,i])==str:
        print(i,type(result.loc[0,i]))
# Out:
# host_response_time <class 'str'>
# neighbourhood_cleansed <class 'str'>
# property_type <class 'str'>
# room_type <class 'str'>

# %%
from sklearn.preprocessing import OneHotEncoder
def encoder(name,result):
    """对分类数据进行独热编码"""
    clf=OneHotEncoder()
    temp=result.loc[:,name].copy().to_numpy()
    temp.shape=(len(temp),1)
    temp[temp==0]="nan"
    temp=clf.fit_transform(temp)
    result.loc[:,[name+str(i) for i in range(0,len(pd.unique(result.loc[:,name])))]]=temp.todense()
    # result.loc[:,name]=temp
    return result.drop(name,axis=1)
    
result=encoder("host_response_time",result)
result=encoder("property_type",result)
result=encoder("room_type",result)
result=encoder("neighbourhood_cleansed",result)

# %%
# 在填补剩下的缺失值之前需要对变量进行其他操作
from sklearn.impute import KNNImputer
clf=KNNImputer()
result=pd.DataFrame(clf.fit_transform(result),columns=result.columns,index=result.index)
print("清洗数据结束，展示最终结果：")
describe(result)
# Out:
# 清洗数据结束，展示最终结果：
# ======================================================================
# 表格形状： (26204, 95)
# 结果：
#                               独立元素个数  缺失值个数    独立元素比例
# listing_id                     4919      0  0.187719
# adjusted_price                 4552      0  0.173714
# notavailable                   1390      0  0.053045
# sentiment                      3124      0  0.119218
# is_description                    2      0  0.000076
# is_neighborhood_overview          2      0  0.000076
# is_host_about                     2      0  0.000076
# host_response_rate               36      0  0.001374
# host_acceptance_rate             34      0  0.001298
# host_is_superhost                 2      0  0.000076
# host_listings_count              36      0  0.001374
# host_total_listings_count        36      0  0.001374
# host_verifications                4      0  0.000153
# host_has_profile_pic              2      0  0.000076
# host_identity_verified            1      0  0.000038
# latitude                       3966      0  0.151351
# longitude                      3974      0  0.151656
# accommodates                     16      0  0.000611
# bedrooms                         32      0  0.001221
# beds                             32      0  0.001221
# minimum_nights                   11      0  0.000420
# maximum_nights                   54      0  0.002061
# number_of_reviews_ltm            51      0  0.001946
# number_of_reviews_l30d           10      0  0.000382
# review_scores_rating            226      0  0.008625
# review_scores_accuracy          170      0  0.006488
# review_scores_cleanliness       203      0  0.007747
# review_scores_checkin           146      0  0.005572
# review_scores_communication     143      0  0.005457
# review_scores_location          182      0  0.006946
# review_scores_value             223      0  0.008510
# instant_bookable                  2      0  0.000076
# reviews_per_month               284      0  0.010838
# bathrooms                        37      0  0.001412
# host_time                      1041      0  0.039727
# host_response_time0               2      0  0.000076
# host_response_time1               2      0  0.000076
# host_response_time2               2      0  0.000076
# host_response_time3               2      0  0.000076
# property_type0                    2      0  0.000076
# property_type1                    2      0  0.000076
# property_type2                    2      0  0.000076
# property_type3                    2      0  0.000076
# property_type4                    2      0  0.000076
# property_type5                    2      0  0.000076
# property_type6                    2      0  0.000076
# property_type7                    2      0  0.000076
# property_type8                    2      0  0.000076
# property_type9                    2      0  0.000076
# property_type10                   2      0  0.000076
# property_type11                   2      0  0.000076
# property_type12                   2      0  0.000076
# property_type13                   2      0  0.000076
# property_type14                   2      0  0.000076
# property_type15                   2      0  0.000076
# property_type16                   2      0  0.000076
# property_type17                   2      0  0.000076
# property_type18                   2      0  0.000076
# property_type19                   2      0  0.000076
# property_type20                   2      0  0.000076
# property_type21                   2      0  0.000076
# property_type22                   2      0  0.000076
# property_type23                   2      0  0.000076
# property_type24                   2      0  0.000076
# property_type25                   2      0  0.000076
# property_type26                   2      0  0.000076
# property_type27                   2      0  0.000076
# property_type28                   2      0  0.000076
# property_type29                   2      0  0.000076
# property_type30                   2      0  0.000076
# property_type31                   2      0  0.000076
# property_type32                   2      0  0.000076
# property_type33                   2      0  0.000076
# property_type34                   2      0  0.000076
# property_type35                   2      0  0.000076
# property_type36                   2      0  0.000076
# room_type0                        2      0  0.000076
# room_type1                        2      0  0.000076
# room_type2                        2      0  0.000076
# neighbourhood_cleansed0           2      0  0.000076
# neighbourhood_cleansed1           2      0  0.000076
# neighbourhood_cleansed2           2      0  0.000076
# neighbourhood_cleansed3           2      0  0.000076
# neighbourhood_cleansed4           2      0  0.000076
# neighbourhood_cleansed5           2      0  0.000076
# neighbourhood_cleansed6           2      0  0.000076
# neighbourhood_cleansed7           2      0  0.000076
# neighbourhood_cleansed8           2      0  0.000076
# neighbourhood_cleansed9           2      0  0.000076
# neighbourhood_cleansed10          2      0  0.000076
# neighbourhood_cleansed11          2      0  0.000076
# neighbourhood_cleansed12          2      0  0.000076
# neighbourhood_cleansed13          2      0  0.000076
# neighbourhood_cleansed14          2      0  0.000076
# neighbourhood_cleansed15          2      0  0.000076
# ======================================================================

# %%
result.to_csv(write_file)
