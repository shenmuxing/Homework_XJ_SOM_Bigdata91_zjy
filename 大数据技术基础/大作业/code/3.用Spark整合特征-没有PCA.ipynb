# %% [markdown]
# ## 文件前提
# * 左侧：data.csv,test.csv原始文件
# * test_人工提取特征.csv,train_人工提取特征.csv是1.ipynb生成的
# * 大数据基础model是在colab中预训练得到的model,用来提取及其特征
# * 这个耗时很长

# %%
import numpy as np
import pandas as pd
import time
import cv2 
import torch
from torchvision import datasets,models,transforms,utils
from torch.utils.data import DataLoader,Dataset
from torchsummary import summary
import torch.nn as nn
import matplotlib.pyplot as plt
from PIL import Image
import os
import PIL
PIL.Image.MAX_IMAGE_PIXELS = 933120000
from pyspark.ml.linalg import DenseVector
from pyspark.sql import SparkSession
from pyspark.sql.types import StringType,StructField,StructType,FloatType,IntegerType
from pyspark.sql.functions import udf
spark=SparkSession.builder.master("local").appName("大数据大作业-整合特征").getOrCreate()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
from pyspark.ml import feature as ft
# Enable Arrow support.
spark.conf.set("spark.sql.execution.arrow.enabled", "true")
spark.conf.set("spark.sql.execution.arrow.maxRecordsPerBatch", "64")
# 搭一个spark的环境
sc=spark.sparkContext
sc
# Out:
# <SparkContext master=local appName=大数据大作业-整合特征>

# %% [markdown]
# ## 特征一：原表格自带的特征+提前提取好的特征

# %%
def Read_df_raw(filename):
    """读取train和test原始文件"""
    df_data_raw=spark.read.csv(filename,header=True)
    def train():
        return "train"
    def test():
        return "test"
    train_udf=udf(train,StringType())
    test_udf=udf(test,StringType())
    if "data" in filename:# 给train加一列叫"train"
        df_data_raw=df_data_raw.withColumn("train_or_test",train_udf())
    else :
        df_data_raw=df_data_raw.withColumn("train_or_test",test_udf())
    print("读取原始文件完成：")
    df_data_raw.show(5)
    return df_data_raw
def Read_human(filename):
    """读取人工提取的特征"""
    data_human=pd.read_csv(filename,index_col=0)
    data_human.index=[i for i in range(0,len(data_human.index))]
    df_data_human=spark.createDataFrame(data_human.values.tolist(),data_human.columns.tolist())
    print("读取人工提取特征文件完成：")
    df_data_human.printSchema()
    return df_data_human

# %%
df_data_raw=Read_df_raw("data.csv")
df_data_human=Read_human("train_人工提取特征.csv")
# Out:
# 读取原始文件完成：
# +----------+----------------+-----+------------------+--------+--------+-------------+--------------------+-------------+
# |product_id|product_category|brand|             price|quantity|favorite|negative_info|           image_url|train_or_test|
# +----------+----------------+-----+------------------+--------+--------+-------------+--------------------+-------------+
# |         1|               2|    2|127778.66305461951|       1|    1056|            0|https://lh3.googl...|        train|
# |         2|               1|    1|           3250.34|       1|       2|            1|https://lh3.googl...|        train|
# |         3|               1|    1| 977.9385000000001|       1|       2|            1|https://lh3.googl...|        train|
# |         4|               1|    1| 977.9385000000001|       1|       2|            1|https://lh3.googl...|        train|
# |         5|               1|    1|1776.1040000000003|       1|       0|            0|https://lh3.googl...|        train|
# +----------+----------------+-----+------------------+--------+--------+-------------+--------------------+-------------+
# only showing top 5 rows
#
# 读取人工提取特征文件完成：
# root
#  |-- product_id: double (nullable = true)
#  |-- coner_numbers: double (nullable = true)
#  |-- face_numbers: double (nullable = true)
#  |-- face_x: double (nullable = true)
#  |-- faces_y: double (nullable = true)
#  |-- face_size: double (nullable = true)
#  |-- keypoint: double (nullable = true)
#  |-- contour_numbers: double (nullable = true)
#  |-- h1: double (nullable = true)
#  |-- h2: double (nullable = true)
#  |-- h3: double (nullable = true)
#  |-- s1: double (nullable = true)
#  |-- s2: double (nullable = true)
#  |-- s3: double (nullable = true)
#  |-- v1: double (nullable = true)
#  |-- v2: double (nullable = true)
#  |-- v3: double (nullable = true)
#  |-- text_regions: double (nullable = true)

# %%
# 从pytorch导入模型
class AdaptiveConcatPool2d(nn.Module):
    def __init__(self,sz=None):
        super().__init__()
        sz=sz or (1,1)
        self.ap=nn.AdaptiveAvgPool2d(sz)
        self.mp=nn.AdaptiveMaxPool2d(sz)
    def forward(self,x):
        return torch.cat([self.mp(x),self.ap(x)],1)
def get_model():
    model=torch.load("大数据技术基础model", map_location=torch.device('cpu'))
    #对最后一层进行社会主义改造，把它变成输出512个元素的乖宝宝
    new_fc=nn.Sequential(
            nn.Flatten(),
            nn.BatchNorm1d(4096),
            nn.Dropout(0.5),
            nn.Linear(4096,512),
            nn.ReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.5)
        )
    state=model.fc.state_dict()
    state.pop("7.weight")
    state.pop("7.bias")
    new_fc.load_state_dict(state)
    model.fc=new_fc
    print("模型已装载...")
    return model
enumerate
class ImageDataset(Dataset):
    def __init__(self,paths,transform=None) -> None:
        super().__init__()
        self.paths=paths
        self.transform=transform
    def __len__(self):
        return len(self.paths)
    def __getitem__(self, index):
        image = datasets.folder.default_loader(self.paths[index])
        if self.transform is not None:
            image = self.transform(image)
        return image

datadir = 'E:/python/大数据技术基础/大作业/img/mydata/'
traindir = datadir + 'train/'
testdir = datadir + 'test/'
def get_paths(dir_name):
    paths=[]
    for i in os.listdir(dir_name):
        if os.path.isdir(i):
            continue
        else:
            paths.append(dir_name+i)
    return paths

train_paths=get_paths(traindir)
test_paths=get_paths(testdir)

# %%
# 定义预测的函数
transform=transforms.Compose([
    transforms.CenterCrop(size=256),
    transforms.ToTensor(),
    transforms.Normalize([0.485,0.456,0.406],[0.229,0.224,0.225])       
])
def predict(train_or_test,product_id):
    """这是一个 udf，
    输入是train还是test的路径，输入product_id，输出上面那个深度神经网络提取到的特征"""
    model.eval()
    if train_or_test=="train":
        path=traindir+product_id+".jpg"
    else:
        path=testdir+product_id+".jpg"
    if not os.path.exists(path):
        res=np.array([None]*512).reshape(512,).tolist()
        res.append(product_id)
        return res
    image = datasets.folder.default_loader(path)
    image=transform(image)
    image=torch.reshape(image,[1,3,256,256])
    model.to(device)
    with torch.no_grad():
        predictions=model(image.to(device)).cpu().numpy().reshape(512,).tolist()
        predictions.append(product_id)
    return predictions
schema=StructType([])
for  i in range(0,512):
    schema.add(StructField(str(i+1),FloatType()))
schema.add(StructField("product_id",StringType()))
predict_udf=udf(predict,schema)#转换成udf

model=get_model()#fbm:feature_by_machine
# Out:
# 模型已装载...

# %%
#把模型训练一下
df_data_machine=df_data_raw.withColumn("fbm",predict_udf("train_or_test","product_id")).select("fbm").rdd.flatMap(lambda x:x).toDF(schema).dropna(thresh=2)

# %%
# len_pca=50# 假定这个世界是光滑的
# def Get_feature_pca(df_machine):
#     def pca_to_array(product_id,pca_features):
#         """把pca_features的列返回为一个np.array()"""
#         res=pca_features.toArray().tolist()#rdd.flatMap(lambda x:x).collect()[0].toArray().tolist()
#         res.append(str(product_id))
#         return res
#     schema_pca=StructType([])
#     for  i in range(0,len_pca):
#         schema_pca.add(StructField(str(i+1),FloatType()))
#     schema_pca.add(StructField("product_id",StringType()))
#     pca_to_array_udf=udf(pca_to_array,schema_pca)#转换成udf
    
#     df_data_machine_features=ft.VectorAssembler(inputCols=df_machine.columns[:-1],outputCol="features")
#     df_data_machine_features=df_data_machine_features.transform(df_machine).select("product_id","features").collect()
#     df_data_machine_features=spark.createDataFrame(df_data_machine_features)    
    
#     pca_model=ft.PCA(k=len_pca,inputCol="features",outputCol="pca_features")
#     pca_model=pca_model.fit(df_data_machine_features)
#     pca_features=pca_model.transform(df_data_machine_features).collect()
#     pca_features=spark.createDataFrame(pca_features).select("product_id","pca_features")
    
#     pca_features=pca_features.withColumn("pca_features",pca_to_array_udf("product_id","pca_features")).select("pca_features").rdd.flatMap(lambda x:x).toDF(schema_pca)
#     print("对机器学习的结果进行PCA操作完成：")
#     pca_features.printSchema()
#     return (pca_model,pca_features)

# %%
# plt.style.use("seaborn")
# plt.rcParams['font.sans-serif']=['SimHei']   # 用黑体显示中文
# plt.rcParams['axes.unicode_minus']=False     # 正常显示负号
# plt.plot(range(0,len_pca),pca_model.explainedVariance.toArray(),"co-")
# plt.xlabel("主成分排名")
# plt.ylabel("主成分重要性")
# plt.title("主成分重要程度")

# %%
df_data_human=df_data_human.withColumn("product_id",df_data_human["product_id"].cast(IntegerType()).cast(StringType()))

# %%
df_all_features=df_data_raw.select("product_id","product_category","brand","price","quantity","favorite","negative_info").join(df_data_human,df_data_raw.product_id==df_data_human.product_id,how="left_outer").drop(df_data_human.product_id)
df_all_features=df_all_features.join(df_data_machine,df_all_features.product_id==df_data_machine.product_id,how="left_outer").drop(df_data_machine.product_id)
df_all_features.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- quantity: string (nullable = true)
#  |-- favorite: string (nullable = true)
#  |-- negative_info: string (nullable = true)
#  |-- coner_numbers: double (nullable = true)
#  |-- face_numbers: double (nullable = true)
#  |-- face_x: double (nullable = true)
#  |-- faces_y: double (nullable = true)
#  |-- face_size: double (nullable = true)
#  |-- keypoint: double (nullable = true)
#  |-- contour_numbers: double (nullable = true)
#  |-- h1: double (nullable = true)
#  |-- h2: double (nullable = true)
#  |-- h3: double (nullable = true)
#  |-- s1: double (nullable = true)
#  |-- s2: double (nullable = true)
#  |-- s3: double (nullable = true)
#  |-- v1: double (nullable = true)
#  |-- v2: double (nullable = true)
#  |-- v3: double (nullable = true)
#  |-- text_regions: double (nullable = true)
#  |-- 1: float (nullable = true)
#  |-- 2: float (nullable = true)
#  |-- 3: float (nullable = true)
#  |-- 4: float (nullable = true)
#  |-- 5: float (nullable = true)
#  |-- 6: float (nullable = true)
#  |-- 7: float (nullable = true)
#  |-- 8: float (nullable = true)
#  |-- 9: float (nullable = true)
#  |-- 10: float (nullable = true)
#  |-- 11: float (nullable = true)
#  |-- 12: float (nullable = true)
#  |-- 13: float (nullable = true)
#  |-- 14: float (nullable = true)
#  |-- 15: float (nullable = true)
#  |-- 16: float (nullable = true)
#  |-- 17: float (nullable = true)
#  |-- 18: float (nullable = true)
#  |-- 19: float (nullable = true)
#  |-- 20: float (nullable = true)
#  |-- 21: float (nullable = true)
#  |-- 22: float (nullable = true)
#  |-- 23: float (nullable = true)
#  |-- 24: float (nullable = true)
#  |-- 25: float (nullable = true)
#  |-- 26: float (nullable = true)
#  |-- 27: float (nullable = true)
#  |-- 28: float (nullable = true)
#  |-- 29: float (nullable = true)
#  |-- 30: float (nullable = true)
#  |-- 31: float (nullable = true)
#  |-- 32: float (nullable = true)
#  |-- 33: float (nullable = true)
#  |-- 34: float (nullable = true)
#  |-- 35: float (nullable = true)
#  |-- 36: float (nullable = true)
#  |-- 37: float (nullable = true)
#  |-- 38: float (nullable = true)
#  |-- 39: float (nullable = true)
#  |-- 40: float (nullable = true)
#  |-- 41: float (nullable = true)
#  |-- 42: float (nullable = true)
#  |-- 43: float (nullable = true)
#  |-- 44: float (nullable = true)
#  |-- 45: float (nullable = true)
#  |-- 46: float (nullable = true)
#  |-- 47: float (nullable = true)
#  |-- 48: float (nullable = true)
#  |-- 49: float (nullable = true)
#  |-- 50: float (nullable = true)
#  |-- 51: float (nullable = true)
#  |-- 52: float (nullable = true)
#  |-- 53: float (nullable = true)
#  |-- 54: float (nullable = true)
#  |-- 55: float (nullable = true)
#  |-- 56: float (nullable = true)
#  |-- 57: float (nullable = true)
#  |-- 58: float (nullable = true)
#  |-- 59: float (nullable = true)
#  |-- 60: float (nullable = true)
#  |-- 61: float (nullable = true)
#  |-- 62: float (nullable = true)
#  |-- 63: float (nullable = true)
#  |-- 64: float (nullable = true)
#  |-- 65: float (nullable = true)
#  |-- 66: float (nullable = true)
#  |-- 67: float (nullable = true)
#  |-- 68: float (nullable = true)
#  |-- 69: float (nullable = true)
#  |-- 70: float (nullable = true)
#  |-- 71: float (nullable = true)
#  |-- 72: float (nullable = true)
#  |-- 73: float (nullable = true)
#  |-- 74: float (nullable = true)
#  |-- 75: float (nullable = true)
#  |-- 76: float (nullable = true)
#  |-- 77: float (nullable = true)
#  |-- 78: float (nullable = true)
#  |-- 79: float (nullable = true)
#  |-- 80: float (nullable = true)
#  |-- 81: float (nullable = true)
#  |-- 82: float (nullable = true)
#  |-- 83: float (nullable = true)
#  |-- 84: float (nullable = true)
#  |-- 85: float (nullable = true)
#  |-- 86: float (nullable = true)
#  |-- 87: float (nullable = true)
#  |-- 88: float (nullable = true)
#  |-- 89: float (nullable = true)
#  |-- 90: float (nullable = true)
#  |-- 91: float (nullable = true)
#  |-- 92: float (nullable = true)
#  |-- 93: float (nullable = true)
#  |-- 94: float (nullable = true)
#  |-- 95: float (nullable = true)
#  |-- 96: float (nullable = true)
#  |-- 97: float (nullable = true)
#  |-- 98: float (nullable = true)
#  |-- 99: float (nullable = true)
#  |-- 100: float (nullable = true)
#  |-- 101: float (nullable = true)
#  |-- 102: float (nullable = true)
#  |-- 103: float (nullable = true)
#  |-- 104: float (nullable = true)
#  |-- 105: float (nullable = true)
#  |-- 106: float (nullable = true)
#  |-- 107: float (nullable = true)
#  |-- 108: float (nullable = true)
#  |-- 109: float (nullable = true)
#  |-- 110: float (nullable = true)
#  |-- 111: float (nullable = true)
#  |-- 112: float (nullable = true)
#  |-- 113: float (nullable = true)
#  |-- 114: float (nullable = true)
#  |-- 115: float (nullable = true)
#  |-- 116: float (nullable = true)
#  |-- 117: float (nullable = true)
#  |-- 118: float (nullable = true)
#  |-- 119: float (nullable = true)
#  |-- 120: float (nullable = true)
#  |-- 121: float (nullable = true)
#  |-- 122: float (nullable = true)
#  |-- 123: float (nullable = true)
#  |-- 124: float (nullable = true)
#  |-- 125: float (nullable = true)
#  |-- 126: float (nullable = true)
#  |-- 127: float (nullable = true)
#  |-- 128: float (nullable = true)
#  |-- 129: float (nullable = true)
#  |-- 130: float (nullable = true)
#  |-- 131: float (nullable = true)
#  |-- 132: float (nullable = true)
#  |-- 133: float (nullable = true)
#  |-- 134: float (nullable = true)
#  |-- 135: float (nullable = true)
#  |-- 136: float (nullable = true)
#  |-- 137: float (nullable = true)
#  |-- 138: float (nullable = true)
#  |-- 139: float (nullable = true)
#  |-- 140: float (nullable = true)
#  |-- 141: float (nullable = true)
#  |-- 142: float (nullable = true)
#  |-- 143: float (nullable = true)
#  |-- 144: float (nullable = true)
#  |-- 145: float (nullable = true)
#  |-- 146: float (nullable = true)
#  |-- 147: float (nullable = true)
#  |-- 148: float (nullable = true)
#  |-- 149: float (nullable = true)
#  |-- 150: float (nullable = true)
#  |-- 151: float (nullable = true)
#  |-- 152: float (nullable = true)
#  |-- 153: float (nullable = true)
#  |-- 154: float (nullable = true)
#  |-- 155: float (nullable = true)
#  |-- 156: float (nullable = true)
#  |-- 157: float (nullable = true)
#  |-- 158: float (nullable = true)
#  |-- 159: float (nullable = true)
#  |-- 160: float (nullable = true)
#  |-- 161: float (nullable = true)
#  |-- 162: float (nullable = true)
#  |-- 163: float (nullable = true)
#  |-- 164: float (nullable = true)
#  |-- 165: float (nullable = true)
#  |-- 166: float (nullable = true)
#  |-- 167: float (nullable = true)
#  |-- 168: float (nullable = true)
#  |-- 169: float (nullable = true)
#  |-- 170: float (nullable = true)
#  |-- 171: float (nullable = true)
#  |-- 172: float (nullable = true)
#  |-- 173: float (nullable = true)
#  |-- 174: float (nullable = true)
#  |-- 175: float (nullable = true)
#  |-- 176: float (nullable = true)
#  |-- 177: float (nullable = true)
#  |-- 178: float (nullable = true)
#  |-- 179: float (nullable = true)
#  |-- 180: float (nullable = true)
#  |-- 181: float (nullable = true)
#  |-- 182: float (nullable = true)
#  |-- 183: float (nullable = true)
#  |-- 184: float (nullable = true)
#  |-- 185: float (nullable = true)
#  |-- 186: float (nullable = true)
#  |-- 187: float (nullable = true)
#  |-- 188: float (nullable = true)
#  |-- 189: float (nullable = true)
#  |-- 190: float (nullable = true)
#  |-- 191: float (nullable = true)
#  |-- 192: float (nullable = true)
#  |-- 193: float (nullable = true)
#  |-- 194: float (nullable = true)
#  |-- 195: float (nullable = true)
#  |-- 196: float (nullable = true)
#  |-- 197: float (nullable = true)
#  |-- 198: float (nullable = true)
#  |-- 199: float (nullable = true)
#  |-- 200: float (nullable = true)
#  |-- 201: float (nullable = true)
#  |-- 202: float (nullable = true)
#  |-- 203: float (nullable = true)
#  |-- 204: float (nullable = true)
#  |-- 205: float (nullable = true)
#  |-- 206: float (nullable = true)
#  |-- 207: float (nullable = true)
#  |-- 208: float (nullable = true)
#  |-- 209: float (nullable = true)
#  |-- 210: float (nullable = true)
#  |-- 211: float (nullable = true)
#  |-- 212: float (nullable = true)
#  |-- 213: float (nullable = true)
#  |-- 214: float (nullable = true)
#  |-- 215: float (nullable = true)
#  |-- 216: float (nullable = true)
#  |-- 217: float (nullable = true)
#  |-- 218: float (nullable = true)
#  |-- 219: float (nullable = true)
#  |-- 220: float (nullable = true)
#  |-- 221: float (nullable = true)
#  |-- 222: float (nullable = true)
#  |-- 223: float (nullable = true)
#  |-- 224: float (nullable = true)
#  |-- 225: float (nullable = true)
#  |-- 226: float (nullable = true)
#  |-- 227: float (nullable = true)
#  |-- 228: float (nullable = true)
#  |-- 229: float (nullable = true)
#  |-- 230: float (nullable = true)
#  |-- 231: float (nullable = true)
#  |-- 232: float (nullable = true)
#  |-- 233: float (nullable = true)
#  |-- 234: float (nullable = true)
#  |-- 235: float (nullable = true)
#  |-- 236: float (nullable = true)
#  |-- 237: float (nullable = true)
#  |-- 238: float (nullable = true)
#  |-- 239: float (nullable = true)
#  |-- 240: float (nullable = true)
#  |-- 241: float (nullable = true)
#  |-- 242: float (nullable = true)
#  |-- 243: float (nullable = true)
#  |-- 244: float (nullable = true)
#  |-- 245: float (nullable = true)
#  |-- 246: float (nullable = true)
#  |-- 247: float (nullable = true)
#  |-- 248: float (nullable = true)
#  |-- 249: float (nullable = true)
#  |-- 250: float (nullable = true)
#  |-- 251: float (nullable = true)
#  |-- 252: float (nullable = true)
#  |-- 253: float (nullable = true)
#  |-- 254: float (nullable = true)
#  |-- 255: float (nullable = true)
#  |-- 256: float (nullable = true)
#  |-- 257: float (nullable = true)
#  |-- 258: float (nullable = true)
#  |-- 259: float (nullable = true)
#  |-- 260: float (nullable = true)
#  |-- 261: float (nullable = true)
#  |-- 262: float (nullable = true)
#  |-- 263: float (nullable = true)
#  |-- 264: float (nullable = true)
#  |-- 265: float (nullable = true)
#  |-- 266: float (nullable = true)
#  |-- 267: float (nullable = true)
#  |-- 268: float (nullable = true)
#  |-- 269: float (nullable = true)
#  |-- 270: float (nullable = true)
#  |-- 271: float (nullable = true)
#  |-- 272: float (nullable = true)
#  |-- 273: float (nullable = true)
#  |-- 274: float (nullable = true)
#  |-- 275: float (nullable = true)
#  |-- 276: float (nullable = true)
#  |-- 277: float (nullable = true)
#  |-- 278: float (nullable = true)
#  |-- 279: float (nullable = true)
#  |-- 280: float (nullable = true)
#  |-- 281: float (nullable = true)
#  |-- 282: float (nullable = true)
#  |-- 283: float (nullable = true)
#  |-- 284: float (nullable = true)
#  |-- 285: float (nullable = true)
#  |-- 286: float (nullable = true)
#  |-- 287: float (nullable = true)
#  |-- 288: float (nullable = true)
#  |-- 289: float (nullable = true)
#  |-- 290: float (nullable = true)
#  |-- 291: float (nullable = true)
#  |-- 292: float (nullable = true)
#  |-- 293: float (nullable = true)
#  |-- 294: float (nullable = true)
#  |-- 295: float (nullable = true)
#  |-- 296: float (nullable = true)
#  |-- 297: float (nullable = true)
#  |-- 298: float (nullable = true)
#  |-- 299: float (nullable = true)
#  |-- 300: float (nullable = true)
#  |-- 301: float (nullable = true)
#  |-- 302: float (nullable = true)
#  |-- 303: float (nullable = true)
#  |-- 304: float (nullable = true)
#  |-- 305: float (nullable = true)
#  |-- 306: float (nullable = true)
#  |-- 307: float (nullable = true)
#  |-- 308: float (nullable = true)
#  |-- 309: float (nullable = true)
#  |-- 310: float (nullable = true)
#  |-- 311: float (nullable = true)
#  |-- 312: float (nullable = true)
#  |-- 313: float (nullable = true)
#  |-- 314: float (nullable = true)
#  |-- 315: float (nullable = true)
#  |-- 316: float (nullable = true)
#  |-- 317: float (nullable = true)
#  |-- 318: float (nullable = true)
#  |-- 319: float (nullable = true)
#  |-- 320: float (nullable = true)
#  |-- 321: float (nullable = true)
#  |-- 322: float (nullable = true)
#  |-- 323: float (nullable = true)
#  |-- 324: float (nullable = true)
#  |-- 325: float (nullable = true)
#  |-- 326: float (nullable = true)
#  |-- 327: float (nullable = true)
#  |-- 328: float (nullable = true)
#  |-- 329: float (nullable = true)
#  |-- 330: float (nullable = true)
#  |-- 331: float (nullable = true)
#  |-- 332: float (nullable = true)
#  |-- 333: float (nullable = true)
#  |-- 334: float (nullable = true)
#  |-- 335: float (nullable = true)
#  |-- 336: float (nullable = true)
#  |-- 337: float (nullable = true)
#  |-- 338: float (nullable = true)
#  |-- 339: float (nullable = true)
#  |-- 340: float (nullable = true)
#  |-- 341: float (nullable = true)
#  |-- 342: float (nullable = true)
#  |-- 343: float (nullable = true)
#  |-- 344: float (nullable = true)
#  |-- 345: float (nullable = true)
#  |-- 346: float (nullable = true)
#  |-- 347: float (nullable = true)
#  |-- 348: float (nullable = true)
#  |-- 349: float (nullable = true)
#  |-- 350: float (nullable = true)
#  |-- 351: float (nullable = true)
#  |-- 352: float (nullable = true)
#  |-- 353: float (nullable = true)
#  |-- 354: float (nullable = true)
#  |-- 355: float (nullable = true)
#  |-- 356: float (nullable = true)
#  |-- 357: float (nullable = true)
#  |-- 358: float (nullable = true)
#  |-- 359: float (nullable = true)
#  |-- 360: float (nullable = true)
#  |-- 361: float (nullable = true)
#  |-- 362: float (nullable = true)
#  |-- 363: float (nullable = true)
#  |-- 364: float (nullable = true)
#  |-- 365: float (nullable = true)
#  |-- 366: float (nullable = true)
#  |-- 367: float (nullable = true)
#  |-- 368: float (nullable = true)
#  |-- 369: float (nullable = true)
#  |-- 370: float (nullable = true)
#  |-- 371: float (nullable = true)
#  |-- 372: float (nullable = true)
#  |-- 373: float (nullable = true)
#  |-- 374: float (nullable = true)
#  |-- 375: float (nullable = true)
#  |-- 376: float (nullable = true)
#  |-- 377: float (nullable = true)
#  |-- 378: float (nullable = true)
#  |-- 379: float (nullable = true)
#  |-- 380: float (nullable = true)
#  |-- 381: float (nullable = true)
#  |-- 382: float (nullable = true)
#  |-- 383: float (nullable = true)
#  |-- 384: float (nullable = true)
#  |-- 385: float (nullable = true)
#  |-- 386: float (nullable = true)
#  |-- 387: float (nullable = true)
#  |-- 388: float (nullable = true)
#  |-- 389: float (nullable = true)
#  |-- 390: float (nullable = true)
#  |-- 391: float (nullable = true)
#  |-- 392: float (nullable = true)
#  |-- 393: float (nullable = true)
#  |-- 394: float (nullable = true)
#  |-- 395: float (nullable = true)
#  |-- 396: float (nullable = true)
#  |-- 397: float (nullable = true)
#  |-- 398: float (nullable = true)
#  |-- 399: float (nullable = true)
#  |-- 400: float (nullable = true)
#  |-- 401: float (nullable = true)
#  |-- 402: float (nullable = true)
#  |-- 403: float (nullable = true)
#  |-- 404: float (nullable = true)
#  |-- 405: float (nullable = true)
#  |-- 406: float (nullable = true)
#  |-- 407: float (nullable = true)
#  |-- 408: float (nullable = true)
#  |-- 409: float (nullable = true)
#  |-- 410: float (nullable = true)
#  |-- 411: float (nullable = true)
#  |-- 412: float (nullable = true)
#  |-- 413: float (nullable = true)
#  |-- 414: float (nullable = true)
#  |-- 415: float (nullable = true)
#  |-- 416: float (nullable = true)
#  |-- 417: float (nullable = true)
#  |-- 418: float (nullable = true)
#  |-- 419: float (nullable = true)
#  |-- 420: float (nullable = true)
#  |-- 421: float (nullable = true)
#  |-- 422: float (nullable = true)
#  |-- 423: float (nullable = true)
#  |-- 424: float (nullable = true)
#  |-- 425: float (nullable = true)
#  |-- 426: float (nullable = true)
#  |-- 427: float (nullable = true)
#  |-- 428: float (nullable = true)
#  |-- 429: float (nullable = true)
#  |-- 430: float (nullable = true)
#  |-- 431: float (nullable = true)
#  |-- 432: float (nullable = true)
#  |-- 433: float (nullable = true)
#  |-- 434: float (nullable = true)
#  |-- 435: float (nullable = true)
#  |-- 436: float (nullable = true)
#  |-- 437: float (nullable = true)
#  |-- 438: float (nullable = true)
#  |-- 439: float (nullable = true)
#  |-- 440: float (nullable = true)
#  |-- 441: float (nullable = true)
#  |-- 442: float (nullable = true)
#  |-- 443: float (nullable = true)
#  |-- 444: float (nullable = true)
#  |-- 445: float (nullable = true)
#  |-- 446: float (nullable = true)
#  |-- 447: float (nullable = true)
#  |-- 448: float (nullable = true)
#  |-- 449: float (nullable = true)
#  |-- 450: float (nullable = true)
#  |-- 451: float (nullable = true)
#  |-- 452: float (nullable = true)
#  |-- 453: float (nullable = true)
#  |-- 454: float (nullable = true)
#  |-- 455: float (nullable = true)
#  |-- 456: float (nullable = true)
#  |-- 457: float (nullable = true)
#  |-- 458: float (nullable = true)
#  |-- 459: float (nullable = true)
#  |-- 460: float (nullable = true)
#  |-- 461: float (nullable = true)
#  |-- 462: float (nullable = true)
#  |-- 463: float (nullable = true)
#  |-- 464: float (nullable = true)
#  |-- 465: float (nullable = true)
#  |-- 466: float (nullable = true)
#  |-- 467: float (nullable = true)
#  |-- 468: float (nullable = true)
#  |-- 469: float (nullable = true)
#  |-- 470: float (nullable = true)
#  |-- 471: float (nullable = true)
#  |-- 472: float (nullable = true)
#  |-- 473: float (nullable = true)
#  |-- 474: float (nullable = true)
#  |-- 475: float (nullable = true)
#  |-- 476: float (nullable = true)
#  |-- 477: float (nullable = true)
#  |-- 478: float (nullable = true)
#  |-- 479: float (nullable = true)
#  |-- 480: float (nullable = true)
#  |-- 481: float (nullable = true)
#  |-- 482: float (nullable = true)
#  |-- 483: float (nullable = true)
#  |-- 484: float (nullable = true)
#  |-- 485: float (nullable = true)
#  |-- 486: float (nullable = true)
#  |-- 487: float (nullable = true)
#  |-- 488: float (nullable = true)
#  |-- 489: float (nullable = true)
#  |-- 490: float (nullable = true)
#  |-- 491: float (nullable = true)
#  |-- 492: float (nullable = true)
#  |-- 493: float (nullable = true)
#  |-- 494: float (nullable = true)
#  |-- 495: float (nullable = true)
#  |-- 496: float (nullable = true)
#  |-- 497: float (nullable = true)
#  |-- 498: float (nullable = true)
#  |-- 499: float (nullable = true)
#  |-- 500: float (nullable = true)
#  |-- 501: float (nullable = true)
#  |-- 502: float (nullable = true)
#  |-- 503: float (nullable = true)
#  |-- 504: float (nullable = true)
#  |-- 505: float (nullable = true)
#  |-- 506: float (nullable = true)
#  |-- 507: float (nullable = true)
#  |-- 508: float (nullable = true)
#  |-- 509: float (nullable = true)
#  |-- 510: float (nullable = true)
#  |-- 511: float (nullable = true)
#  |-- 512: float (nullable = true)

# %%
all_features=df_all_features.toPandas()

# %%
all_features.head()
# Out:
#   product_id product_category brand              price quantity favorite  \
# 0       1090                1     3            171.394        1        0
# 1       1159                1     3  98.38350000000001        1      186
# 2       1436                1     3            36.3296        1        0
# 3       1512                1     5             20.985        1        0
# 4       1572                1     3            168.205        1        0
#
#   negative_info  coner_numbers  face_numbers  face_x  ...       503       504  \
# 0             0         2949.0           0.0     0.0  ... -0.745802 -0.765462
# 1             0          488.0           0.0     0.0  ... -0.745802 -0.765462
# 2             0          695.0           0.0     0.0  ... -0.745802 -0.765462
# 3             0        14067.0           0.0     0.0  ... -0.171421  5.020140
# 4             0         3079.0           0.0     0.0  ... -0.745802 -0.765462
#
#         505       506       507       508       509       510       511  \
# 0 -0.679552 -0.746695 -0.473874 -0.256671  2.044357 -0.069252  0.055398
# 1 -0.679552 -0.746695 -0.558266 -0.540052 -0.770851 -0.778373 -0.706384
# 2 -0.117326  1.016579 -0.635949 -0.540052 -0.770851 -0.778373 -0.706384
# 3  1.230139 -0.353823 -0.635949 -0.540052 -0.770851 -0.778373 -0.706384
# 4 -0.679552 -0.746695 -0.635949  0.691969  1.457456  0.827745 -0.382041
#
#         512
# 0 -0.578162
# 1 -0.578162
# 2  0.395351
# 3  1.207916
# 4 -0.384171
#
# [5 rows x 536 columns]

# %%
all_features.to_csv("train_all_features_noPCA.csv",index=None)

# %% [markdown]
# ## test整合特征部分

# %%
df_test_raw=Read_df_raw("test.csv")
# Out:
# 读取原始文件完成：
# +----------+----------------+-----+------------------+--------+--------+-------------+--------------------+-------------+
# |product_id|product_category|brand|             price|quantity|favorite|negative_info|           image_url|train_or_test|
# +----------+----------------+-----+------------------+--------+--------+-------------+--------------------+-------------+
# |      8001|               3|    4|          75.41336|       1|       0|            0|https://lh3.googl...|         test|
# |      8002|               3|    4|3.1391099999999996|       1|       2|            0|https://lh3.googl...|         test|
# |      8003|               3|    4|252.78960000000004|       1|      38|            0|https://lh3.googl...|         test|
# |      8004|               3|    4|            0.7841|       1|       0|            2|https://lh3.googl...|         test|
# |      8005|               3|    4|           1.44331|       1|       0|            0|https://lh3.googl...|         test|
# +----------+----------------+-----+------------------+--------+--------+-------------+--------------------+-------------+
# only showing top 5 rows

# %%
df_test_human=Read_human("test_人工提取特征.csv")
# Out:
# 读取人工提取特征文件完成：
# root
#  |-- product_id: double (nullable = true)
#  |-- coner_numbers: double (nullable = true)
#  |-- face_numbers: double (nullable = true)
#  |-- face_x: double (nullable = true)
#  |-- faces_y: double (nullable = true)
#  |-- face_size: double (nullable = true)
#  |-- keypoint: double (nullable = true)
#  |-- contour_numbers: double (nullable = true)
#  |-- h1: double (nullable = true)
#  |-- h2: double (nullable = true)
#  |-- h3: double (nullable = true)
#  |-- s1: double (nullable = true)
#  |-- s2: double (nullable = true)
#  |-- s3: double (nullable = true)
#  |-- v1: double (nullable = true)
#  |-- v2: double (nullable = true)
#  |-- v3: double (nullable = true)
#  |-- text_regions: double (nullable = true)

# %%
#简单测试一下能不能用
df_test_machine=df_test_raw.withColumn("fbm",predict_udf("train_or_test","product_id")).select("fbm").rdd.flatMap(lambda x:x).toDF(schema).dropna(thresh=2)
df_test_machine.printSchema()
# Out:
# root
#  |-- 1: float (nullable = true)
#  |-- 2: float (nullable = true)
#  |-- 3: float (nullable = true)
#  |-- 4: float (nullable = true)
#  |-- 5: float (nullable = true)
#  |-- 6: float (nullable = true)
#  |-- 7: float (nullable = true)
#  |-- 8: float (nullable = true)
#  |-- 9: float (nullable = true)
#  |-- 10: float (nullable = true)
#  |-- 11: float (nullable = true)
#  |-- 12: float (nullable = true)
#  |-- 13: float (nullable = true)
#  |-- 14: float (nullable = true)
#  |-- 15: float (nullable = true)
#  |-- 16: float (nullable = true)
#  |-- 17: float (nullable = true)
#  |-- 18: float (nullable = true)
#  |-- 19: float (nullable = true)
#  |-- 20: float (nullable = true)
#  |-- 21: float (nullable = true)
#  |-- 22: float (nullable = true)
#  |-- 23: float (nullable = true)
#  |-- 24: float (nullable = true)
#  |-- 25: float (nullable = true)
#  |-- 26: float (nullable = true)
#  |-- 27: float (nullable = true)
#  |-- 28: float (nullable = true)
#  |-- 29: float (nullable = true)
#  |-- 30: float (nullable = true)
#  |-- 31: float (nullable = true)
#  |-- 32: float (nullable = true)
#  |-- 33: float (nullable = true)
#  |-- 34: float (nullable = true)
#  |-- 35: float (nullable = true)
#  |-- 36: float (nullable = true)
#  |-- 37: float (nullable = true)
#  |-- 38: float (nullable = true)
#  |-- 39: float (nullable = true)
#  |-- 40: float (nullable = true)
#  |-- 41: float (nullable = true)
#  |-- 42: float (nullable = true)
#  |-- 43: float (nullable = true)
#  |-- 44: float (nullable = true)
#  |-- 45: float (nullable = true)
#  |-- 46: float (nullable = true)
#  |-- 47: float (nullable = true)
#  |-- 48: float (nullable = true)
#  |-- 49: float (nullable = true)
#  |-- 50: float (nullable = true)
#  |-- 51: float (nullable = true)
#  |-- 52: float (nullable = true)
#  |-- 53: float (nullable = true)
#  |-- 54: float (nullable = true)
#  |-- 55: float (nullable = true)
#  |-- 56: float (nullable = true)
#  |-- 57: float (nullable = true)
#  |-- 58: float (nullable = true)
#  |-- 59: float (nullable = true)
#  |-- 60: float (nullable = true)
#  |-- 61: float (nullable = true)
#  |-- 62: float (nullable = true)
#  |-- 63: float (nullable = true)
#  |-- 64: float (nullable = true)
#  |-- 65: float (nullable = true)
#  |-- 66: float (nullable = true)
#  |-- 67: float (nullable = true)
#  |-- 68: float (nullable = true)
#  |-- 69: float (nullable = true)
#  |-- 70: float (nullable = true)
#  |-- 71: float (nullable = true)
#  |-- 72: float (nullable = true)
#  |-- 73: float (nullable = true)
#  |-- 74: float (nullable = true)
#  |-- 75: float (nullable = true)
#  |-- 76: float (nullable = true)
#  |-- 77: float (nullable = true)
#  |-- 78: float (nullable = true)
#  |-- 79: float (nullable = true)
#  |-- 80: float (nullable = true)
#  |-- 81: float (nullable = true)
#  |-- 82: float (nullable = true)
#  |-- 83: float (nullable = true)
#  |-- 84: float (nullable = true)
#  |-- 85: float (nullable = true)
#  |-- 86: float (nullable = true)
#  |-- 87: float (nullable = true)
#  |-- 88: float (nullable = true)
#  |-- 89: float (nullable = true)
#  |-- 90: float (nullable = true)
#  |-- 91: float (nullable = true)
#  |-- 92: float (nullable = true)
#  |-- 93: float (nullable = true)
#  |-- 94: float (nullable = true)
#  |-- 95: float (nullable = true)
#  |-- 96: float (nullable = true)
#  |-- 97: float (nullable = true)
#  |-- 98: float (nullable = true)
#  |-- 99: float (nullable = true)
#  |-- 100: float (nullable = true)
#  |-- 101: float (nullable = true)
#  |-- 102: float (nullable = true)
#  |-- 103: float (nullable = true)
#  |-- 104: float (nullable = true)
#  |-- 105: float (nullable = true)
#  |-- 106: float (nullable = true)
#  |-- 107: float (nullable = true)
#  |-- 108: float (nullable = true)
#  |-- 109: float (nullable = true)
#  |-- 110: float (nullable = true)
#  |-- 111: float (nullable = true)
#  |-- 112: float (nullable = true)
#  |-- 113: float (nullable = true)
#  |-- 114: float (nullable = true)
#  |-- 115: float (nullable = true)
#  |-- 116: float (nullable = true)
#  |-- 117: float (nullable = true)
#  |-- 118: float (nullable = true)
#  |-- 119: float (nullable = true)
#  |-- 120: float (nullable = true)
#  |-- 121: float (nullable = true)
#  |-- 122: float (nullable = true)
#  |-- 123: float (nullable = true)
#  |-- 124: float (nullable = true)
#  |-- 125: float (nullable = true)
#  |-- 126: float (nullable = true)
#  |-- 127: float (nullable = true)
#  |-- 128: float (nullable = true)
#  |-- 129: float (nullable = true)
#  |-- 130: float (nullable = true)
#  |-- 131: float (nullable = true)
#  |-- 132: float (nullable = true)
#  |-- 133: float (nullable = true)
#  |-- 134: float (nullable = true)
#  |-- 135: float (nullable = true)
#  |-- 136: float (nullable = true)
#  |-- 137: float (nullable = true)
#  |-- 138: float (nullable = true)
#  |-- 139: float (nullable = true)
#  |-- 140: float (nullable = true)
#  |-- 141: float (nullable = true)
#  |-- 142: float (nullable = true)
#  |-- 143: float (nullable = true)
#  |-- 144: float (nullable = true)
#  |-- 145: float (nullable = true)
#  |-- 146: float (nullable = true)
#  |-- 147: float (nullable = true)
#  |-- 148: float (nullable = true)
#  |-- 149: float (nullable = true)
#  |-- 150: float (nullable = true)
#  |-- 151: float (nullable = true)
#  |-- 152: float (nullable = true)
#  |-- 153: float (nullable = true)
#  |-- 154: float (nullable = true)
#  |-- 155: float (nullable = true)
#  |-- 156: float (nullable = true)
#  |-- 157: float (nullable = true)
#  |-- 158: float (nullable = true)
#  |-- 159: float (nullable = true)
#  |-- 160: float (nullable = true)
#  |-- 161: float (nullable = true)
#  |-- 162: float (nullable = true)
#  |-- 163: float (nullable = true)
#  |-- 164: float (nullable = true)
#  |-- 165: float (nullable = true)
#  |-- 166: float (nullable = true)
#  |-- 167: float (nullable = true)
#  |-- 168: float (nullable = true)
#  |-- 169: float (nullable = true)
#  |-- 170: float (nullable = true)
#  |-- 171: float (nullable = true)
#  |-- 172: float (nullable = true)
#  |-- 173: float (nullable = true)
#  |-- 174: float (nullable = true)
#  |-- 175: float (nullable = true)
#  |-- 176: float (nullable = true)
#  |-- 177: float (nullable = true)
#  |-- 178: float (nullable = true)
#  |-- 179: float (nullable = true)
#  |-- 180: float (nullable = true)
#  |-- 181: float (nullable = true)
#  |-- 182: float (nullable = true)
#  |-- 183: float (nullable = true)
#  |-- 184: float (nullable = true)
#  |-- 185: float (nullable = true)
#  |-- 186: float (nullable = true)
#  |-- 187: float (nullable = true)
#  |-- 188: float (nullable = true)
#  |-- 189: float (nullable = true)
#  |-- 190: float (nullable = true)
#  |-- 191: float (nullable = true)
#  |-- 192: float (nullable = true)
#  |-- 193: float (nullable = true)
#  |-- 194: float (nullable = true)
#  |-- 195: float (nullable = true)
#  |-- 196: float (nullable = true)
#  |-- 197: float (nullable = true)
#  |-- 198: float (nullable = true)
#  |-- 199: float (nullable = true)
#  |-- 200: float (nullable = true)
#  |-- 201: float (nullable = true)
#  |-- 202: float (nullable = true)
#  |-- 203: float (nullable = true)
#  |-- 204: float (nullable = true)
#  |-- 205: float (nullable = true)
#  |-- 206: float (nullable = true)
#  |-- 207: float (nullable = true)
#  |-- 208: float (nullable = true)
#  |-- 209: float (nullable = true)
#  |-- 210: float (nullable = true)
#  |-- 211: float (nullable = true)
#  |-- 212: float (nullable = true)
#  |-- 213: float (nullable = true)
#  |-- 214: float (nullable = true)
#  |-- 215: float (nullable = true)
#  |-- 216: float (nullable = true)
#  |-- 217: float (nullable = true)
#  |-- 218: float (nullable = true)
#  |-- 219: float (nullable = true)
#  |-- 220: float (nullable = true)
#  |-- 221: float (nullable = true)
#  |-- 222: float (nullable = true)
#  |-- 223: float (nullable = true)
#  |-- 224: float (nullable = true)
#  |-- 225: float (nullable = true)
#  |-- 226: float (nullable = true)
#  |-- 227: float (nullable = true)
#  |-- 228: float (nullable = true)
#  |-- 229: float (nullable = true)
#  |-- 230: float (nullable = true)
#  |-- 231: float (nullable = true)
#  |-- 232: float (nullable = true)
#  |-- 233: float (nullable = true)
#  |-- 234: float (nullable = true)
#  |-- 235: float (nullable = true)
#  |-- 236: float (nullable = true)
#  |-- 237: float (nullable = true)
#  |-- 238: float (nullable = true)
#  |-- 239: float (nullable = true)
#  |-- 240: float (nullable = true)
#  |-- 241: float (nullable = true)
#  |-- 242: float (nullable = true)
#  |-- 243: float (nullable = true)
#  |-- 244: float (nullable = true)
#  |-- 245: float (nullable = true)
#  |-- 246: float (nullable = true)
#  |-- 247: float (nullable = true)
#  |-- 248: float (nullable = true)
#  |-- 249: float (nullable = true)
#  |-- 250: float (nullable = true)
#  |-- 251: float (nullable = true)
#  |-- 252: float (nullable = true)
#  |-- 253: float (nullable = true)
#  |-- 254: float (nullable = true)
#  |-- 255: float (nullable = true)
#  |-- 256: float (nullable = true)
#  |-- 257: float (nullable = true)
#  |-- 258: float (nullable = true)
#  |-- 259: float (nullable = true)
#  |-- 260: float (nullable = true)
#  |-- 261: float (nullable = true)
#  |-- 262: float (nullable = true)
#  |-- 263: float (nullable = true)
#  |-- 264: float (nullable = true)
#  |-- 265: float (nullable = true)
#  |-- 266: float (nullable = true)
#  |-- 267: float (nullable = true)
#  |-- 268: float (nullable = true)
#  |-- 269: float (nullable = true)
#  |-- 270: float (nullable = true)
#  |-- 271: float (nullable = true)
#  |-- 272: float (nullable = true)
#  |-- 273: float (nullable = true)
#  |-- 274: float (nullable = true)
#  |-- 275: float (nullable = true)
#  |-- 276: float (nullable = true)
#  |-- 277: float (nullable = true)
#  |-- 278: float (nullable = true)
#  |-- 279: float (nullable = true)
#  |-- 280: float (nullable = true)
#  |-- 281: float (nullable = true)
#  |-- 282: float (nullable = true)
#  |-- 283: float (nullable = true)
#  |-- 284: float (nullable = true)
#  |-- 285: float (nullable = true)
#  |-- 286: float (nullable = true)
#  |-- 287: float (nullable = true)
#  |-- 288: float (nullable = true)
#  |-- 289: float (nullable = true)
#  |-- 290: float (nullable = true)
#  |-- 291: float (nullable = true)
#  |-- 292: float (nullable = true)
#  |-- 293: float (nullable = true)
#  |-- 294: float (nullable = true)
#  |-- 295: float (nullable = true)
#  |-- 296: float (nullable = true)
#  |-- 297: float (nullable = true)
#  |-- 298: float (nullable = true)
#  |-- 299: float (nullable = true)
#  |-- 300: float (nullable = true)
#  |-- 301: float (nullable = true)
#  |-- 302: float (nullable = true)
#  |-- 303: float (nullable = true)
#  |-- 304: float (nullable = true)
#  |-- 305: float (nullable = true)
#  |-- 306: float (nullable = true)
#  |-- 307: float (nullable = true)
#  |-- 308: float (nullable = true)
#  |-- 309: float (nullable = true)
#  |-- 310: float (nullable = true)
#  |-- 311: float (nullable = true)
#  |-- 312: float (nullable = true)
#  |-- 313: float (nullable = true)
#  |-- 314: float (nullable = true)
#  |-- 315: float (nullable = true)
#  |-- 316: float (nullable = true)
#  |-- 317: float (nullable = true)
#  |-- 318: float (nullable = true)
#  |-- 319: float (nullable = true)
#  |-- 320: float (nullable = true)
#  |-- 321: float (nullable = true)
#  |-- 322: float (nullable = true)
#  |-- 323: float (nullable = true)
#  |-- 324: float (nullable = true)
#  |-- 325: float (nullable = true)
#  |-- 326: float (nullable = true)
#  |-- 327: float (nullable = true)
#  |-- 328: float (nullable = true)
#  |-- 329: float (nullable = true)
#  |-- 330: float (nullable = true)
#  |-- 331: float (nullable = true)
#  |-- 332: float (nullable = true)
#  |-- 333: float (nullable = true)
#  |-- 334: float (nullable = true)
#  |-- 335: float (nullable = true)
#  |-- 336: float (nullable = true)
#  |-- 337: float (nullable = true)
#  |-- 338: float (nullable = true)
#  |-- 339: float (nullable = true)
#  |-- 340: float (nullable = true)
#  |-- 341: float (nullable = true)
#  |-- 342: float (nullable = true)
#  |-- 343: float (nullable = true)
#  |-- 344: float (nullable = true)
#  |-- 345: float (nullable = true)
#  |-- 346: float (nullable = true)
#  |-- 347: float (nullable = true)
#  |-- 348: float (nullable = true)
#  |-- 349: float (nullable = true)
#  |-- 350: float (nullable = true)
#  |-- 351: float (nullable = true)
#  |-- 352: float (nullable = true)
#  |-- 353: float (nullable = true)
#  |-- 354: float (nullable = true)
#  |-- 355: float (nullable = true)
#  |-- 356: float (nullable = true)
#  |-- 357: float (nullable = true)
#  |-- 358: float (nullable = true)
#  |-- 359: float (nullable = true)
#  |-- 360: float (nullable = true)
#  |-- 361: float (nullable = true)
#  |-- 362: float (nullable = true)
#  |-- 363: float (nullable = true)
#  |-- 364: float (nullable = true)
#  |-- 365: float (nullable = true)
#  |-- 366: float (nullable = true)
#  |-- 367: float (nullable = true)
#  |-- 368: float (nullable = true)
#  |-- 369: float (nullable = true)
#  |-- 370: float (nullable = true)
#  |-- 371: float (nullable = true)
#  |-- 372: float (nullable = true)
#  |-- 373: float (nullable = true)
#  |-- 374: float (nullable = true)
#  |-- 375: float (nullable = true)
#  |-- 376: float (nullable = true)
#  |-- 377: float (nullable = true)
#  |-- 378: float (nullable = true)
#  |-- 379: float (nullable = true)
#  |-- 380: float (nullable = true)
#  |-- 381: float (nullable = true)
#  |-- 382: float (nullable = true)
#  |-- 383: float (nullable = true)
#  |-- 384: float (nullable = true)
#  |-- 385: float (nullable = true)
#  |-- 386: float (nullable = true)
#  |-- 387: float (nullable = true)
#  |-- 388: float (nullable = true)
#  |-- 389: float (nullable = true)
#  |-- 390: float (nullable = true)
#  |-- 391: float (nullable = true)
#  |-- 392: float (nullable = true)
#  |-- 393: float (nullable = true)
#  |-- 394: float (nullable = true)
#  |-- 395: float (nullable = true)
#  |-- 396: float (nullable = true)
#  |-- 397: float (nullable = true)
#  |-- 398: float (nullable = true)
#  |-- 399: float (nullable = true)
#  |-- 400: float (nullable = true)
#  |-- 401: float (nullable = true)
#  |-- 402: float (nullable = true)
#  |-- 403: float (nullable = true)
#  |-- 404: float (nullable = true)
#  |-- 405: float (nullable = true)
#  |-- 406: float (nullable = true)
#  |-- 407: float (nullable = true)
#  |-- 408: float (nullable = true)
#  |-- 409: float (nullable = true)
#  |-- 410: float (nullable = true)
#  |-- 411: float (nullable = true)
#  |-- 412: float (nullable = true)
#  |-- 413: float (nullable = true)
#  |-- 414: float (nullable = true)
#  |-- 415: float (nullable = true)
#  |-- 416: float (nullable = true)
#  |-- 417: float (nullable = true)
#  |-- 418: float (nullable = true)
#  |-- 419: float (nullable = true)
#  |-- 420: float (nullable = true)
#  |-- 421: float (nullable = true)
#  |-- 422: float (nullable = true)
#  |-- 423: float (nullable = true)
#  |-- 424: float (nullable = true)
#  |-- 425: float (nullable = true)
#  |-- 426: float (nullable = true)
#  |-- 427: float (nullable = true)
#  |-- 428: float (nullable = true)
#  |-- 429: float (nullable = true)
#  |-- 430: float (nullable = true)
#  |-- 431: float (nullable = true)
#  |-- 432: float (nullable = true)
#  |-- 433: float (nullable = true)
#  |-- 434: float (nullable = true)
#  |-- 435: float (nullable = true)
#  |-- 436: float (nullable = true)
#  |-- 437: float (nullable = true)
#  |-- 438: float (nullable = true)
#  |-- 439: float (nullable = true)
#  |-- 440: float (nullable = true)
#  |-- 441: float (nullable = true)
#  |-- 442: float (nullable = true)
#  |-- 443: float (nullable = true)
#  |-- 444: float (nullable = true)
#  |-- 445: float (nullable = true)
#  |-- 446: float (nullable = true)
#  |-- 447: float (nullable = true)
#  |-- 448: float (nullable = true)
#  |-- 449: float (nullable = true)
#  |-- 450: float (nullable = true)
#  |-- 451: float (nullable = true)
#  |-- 452: float (nullable = true)
#  |-- 453: float (nullable = true)
#  |-- 454: float (nullable = true)
#  |-- 455: float (nullable = true)
#  |-- 456: float (nullable = true)
#  |-- 457: float (nullable = true)
#  |-- 458: float (nullable = true)
#  |-- 459: float (nullable = true)
#  |-- 460: float (nullable = true)
#  |-- 461: float (nullable = true)
#  |-- 462: float (nullable = true)
#  |-- 463: float (nullable = true)
#  |-- 464: float (nullable = true)
#  |-- 465: float (nullable = true)
#  |-- 466: float (nullable = true)
#  |-- 467: float (nullable = true)
#  |-- 468: float (nullable = true)
#  |-- 469: float (nullable = true)
#  |-- 470: float (nullable = true)
#  |-- 471: float (nullable = true)
#  |-- 472: float (nullable = true)
#  |-- 473: float (nullable = true)
#  |-- 474: float (nullable = true)
#  |-- 475: float (nullable = true)
#  |-- 476: float (nullable = true)
#  |-- 477: float (nullable = true)
#  |-- 478: float (nullable = true)
#  |-- 479: float (nullable = true)
#  |-- 480: float (nullable = true)
#  |-- 481: float (nullable = true)
#  |-- 482: float (nullable = true)
#  |-- 483: float (nullable = true)
#  |-- 484: float (nullable = true)
#  |-- 485: float (nullable = true)
#  |-- 486: float (nullable = true)
#  |-- 487: float (nullable = true)
#  |-- 488: float (nullable = true)
#  |-- 489: float (nullable = true)
#  |-- 490: float (nullable = true)
#  |-- 491: float (nullable = true)
#  |-- 492: float (nullable = true)
#  |-- 493: float (nullable = true)
#  |-- 494: float (nullable = true)
#  |-- 495: float (nullable = true)
#  |-- 496: float (nullable = true)
#  |-- 497: float (nullable = true)
#  |-- 498: float (nullable = true)
#  |-- 499: float (nullable = true)
#  |-- 500: float (nullable = true)
#  |-- 501: float (nullable = true)
#  |-- 502: float (nullable = true)
#  |-- 503: float (nullable = true)
#  |-- 504: float (nullable = true)
#  |-- 505: float (nullable = true)
#  |-- 506: float (nullable = true)
#  |-- 507: float (nullable = true)
#  |-- 508: float (nullable = true)
#  |-- 509: float (nullable = true)
#  |-- 510: float (nullable = true)
#  |-- 511: float (nullable = true)
#  |-- 512: float (nullable = true)
#  |-- product_id: string (nullable = true)

# %%
df_test_human=df_test_human.withColumn("product_id",df_test_human["product_id"].cast(IntegerType()).cast(StringType()))
df_all_features=df_test_raw.select("product_id","product_category","brand","price","quantity","favorite","negative_info").join(df_test_human,df_test_raw.product_id==df_test_human.product_id,how="left_outer").drop(df_test_human.product_id)
df_all_features=df_all_features.join(df_test_machine,df_all_features.product_id==df_test_machine.product_id,how="left_outer").drop(df_test_machine.product_id)
print("整合之后所有特征的结构如下：")
df_all_features.printSchema()
# Out:
# 整合之后所有特征的结构如下：
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- quantity: string (nullable = true)
#  |-- favorite: string (nullable = true)
#  |-- negative_info: string (nullable = true)
#  |-- coner_numbers: double (nullable = true)
#  |-- face_numbers: double (nullable = true)
#  |-- face_x: double (nullable = true)
#  |-- faces_y: double (nullable = true)
#  |-- face_size: double (nullable = true)
#  |-- keypoint: double (nullable = true)
#  |-- contour_numbers: double (nullable = true)
#  |-- h1: double (nullable = true)
#  |-- h2: double (nullable = true)
#  |-- h3: double (nullable = true)
#  |-- s1: double (nullable = true)
#  |-- s2: double (nullable = true)
#  |-- s3: double (nullable = true)
#  |-- v1: double (nullable = true)
#  |-- v2: double (nullable = true)
#  |-- v3: double (nullable = true)
#  |-- text_regions: double (nullable = true)
#  |-- 1: float (nullable = true)
#  |-- 2: float (nullable = true)
#  |-- 3: float (nullable = true)
#  |-- 4: float (nullable = true)
#  |-- 5: float (nullable = true)
#  |-- 6: float (nullable = true)
#  |-- 7: float (nullable = true)
#  |-- 8: float (nullable = true)
#  |-- 9: float (nullable = true)
#  |-- 10: float (nullable = true)
#  |-- 11: float (nullable = true)
#  |-- 12: float (nullable = true)
#  |-- 13: float (nullable = true)
#  |-- 14: float (nullable = true)
#  |-- 15: float (nullable = true)
#  |-- 16: float (nullable = true)
#  |-- 17: float (nullable = true)
#  |-- 18: float (nullable = true)
#  |-- 19: float (nullable = true)
#  |-- 20: float (nullable = true)
#  |-- 21: float (nullable = true)
#  |-- 22: float (nullable = true)
#  |-- 23: float (nullable = true)
#  |-- 24: float (nullable = true)
#  |-- 25: float (nullable = true)
#  |-- 26: float (nullable = true)
#  |-- 27: float (nullable = true)
#  |-- 28: float (nullable = true)
#  |-- 29: float (nullable = true)
#  |-- 30: float (nullable = true)
#  |-- 31: float (nullable = true)
#  |-- 32: float (nullable = true)
#  |-- 33: float (nullable = true)
#  |-- 34: float (nullable = true)
#  |-- 35: float (nullable = true)
#  |-- 36: float (nullable = true)
#  |-- 37: float (nullable = true)
#  |-- 38: float (nullable = true)
#  |-- 39: float (nullable = true)
#  |-- 40: float (nullable = true)
#  |-- 41: float (nullable = true)
#  |-- 42: float (nullable = true)
#  |-- 43: float (nullable = true)
#  |-- 44: float (nullable = true)
#  |-- 45: float (nullable = true)
#  |-- 46: float (nullable = true)
#  |-- 47: float (nullable = true)
#  |-- 48: float (nullable = true)
#  |-- 49: float (nullable = true)
#  |-- 50: float (nullable = true)
#  |-- 51: float (nullable = true)
#  |-- 52: float (nullable = true)
#  |-- 53: float (nullable = true)
#  |-- 54: float (nullable = true)
#  |-- 55: float (nullable = true)
#  |-- 56: float (nullable = true)
#  |-- 57: float (nullable = true)
#  |-- 58: float (nullable = true)
#  |-- 59: float (nullable = true)
#  |-- 60: float (nullable = true)
#  |-- 61: float (nullable = true)
#  |-- 62: float (nullable = true)
#  |-- 63: float (nullable = true)
#  |-- 64: float (nullable = true)
#  |-- 65: float (nullable = true)
#  |-- 66: float (nullable = true)
#  |-- 67: float (nullable = true)
#  |-- 68: float (nullable = true)
#  |-- 69: float (nullable = true)
#  |-- 70: float (nullable = true)
#  |-- 71: float (nullable = true)
#  |-- 72: float (nullable = true)
#  |-- 73: float (nullable = true)
#  |-- 74: float (nullable = true)
#  |-- 75: float (nullable = true)
#  |-- 76: float (nullable = true)
#  |-- 77: float (nullable = true)
#  |-- 78: float (nullable = true)
#  |-- 79: float (nullable = true)
#  |-- 80: float (nullable = true)
#  |-- 81: float (nullable = true)
#  |-- 82: float (nullable = true)
#  |-- 83: float (nullable = true)
#  |-- 84: float (nullable = true)
#  |-- 85: float (nullable = true)
#  |-- 86: float (nullable = true)
#  |-- 87: float (nullable = true)
#  |-- 88: float (nullable = true)
#  |-- 89: float (nullable = true)
#  |-- 90: float (nullable = true)
#  |-- 91: float (nullable = true)
#  |-- 92: float (nullable = true)
#  |-- 93: float (nullable = true)
#  |-- 94: float (nullable = true)
#  |-- 95: float (nullable = true)
#  |-- 96: float (nullable = true)
#  |-- 97: float (nullable = true)
#  |-- 98: float (nullable = true)
#  |-- 99: float (nullable = true)
#  |-- 100: float (nullable = true)
#  |-- 101: float (nullable = true)
#  |-- 102: float (nullable = true)
#  |-- 103: float (nullable = true)
#  |-- 104: float (nullable = true)
#  |-- 105: float (nullable = true)
#  |-- 106: float (nullable = true)
#  |-- 107: float (nullable = true)
#  |-- 108: float (nullable = true)
#  |-- 109: float (nullable = true)
#  |-- 110: float (nullable = true)
#  |-- 111: float (nullable = true)
#  |-- 112: float (nullable = true)
#  |-- 113: float (nullable = true)
#  |-- 114: float (nullable = true)
#  |-- 115: float (nullable = true)
#  |-- 116: float (nullable = true)
#  |-- 117: float (nullable = true)
#  |-- 118: float (nullable = true)
#  |-- 119: float (nullable = true)
#  |-- 120: float (nullable = true)
#  |-- 121: float (nullable = true)
#  |-- 122: float (nullable = true)
#  |-- 123: float (nullable = true)
#  |-- 124: float (nullable = true)
#  |-- 125: float (nullable = true)
#  |-- 126: float (nullable = true)
#  |-- 127: float (nullable = true)
#  |-- 128: float (nullable = true)
#  |-- 129: float (nullable = true)
#  |-- 130: float (nullable = true)
#  |-- 131: float (nullable = true)
#  |-- 132: float (nullable = true)
#  |-- 133: float (nullable = true)
#  |-- 134: float (nullable = true)
#  |-- 135: float (nullable = true)
#  |-- 136: float (nullable = true)
#  |-- 137: float (nullable = true)
#  |-- 138: float (nullable = true)
#  |-- 139: float (nullable = true)
#  |-- 140: float (nullable = true)
#  |-- 141: float (nullable = true)
#  |-- 142: float (nullable = true)
#  |-- 143: float (nullable = true)
#  |-- 144: float (nullable = true)
#  |-- 145: float (nullable = true)
#  |-- 146: float (nullable = true)
#  |-- 147: float (nullable = true)
#  |-- 148: float (nullable = true)
#  |-- 149: float (nullable = true)
#  |-- 150: float (nullable = true)
#  |-- 151: float (nullable = true)
#  |-- 152: float (nullable = true)
#  |-- 153: float (nullable = true)
#  |-- 154: float (nullable = true)
#  |-- 155: float (nullable = true)
#  |-- 156: float (nullable = true)
#  |-- 157: float (nullable = true)
#  |-- 158: float (nullable = true)
#  |-- 159: float (nullable = true)
#  |-- 160: float (nullable = true)
#  |-- 161: float (nullable = true)
#  |-- 162: float (nullable = true)
#  |-- 163: float (nullable = true)
#  |-- 164: float (nullable = true)
#  |-- 165: float (nullable = true)
#  |-- 166: float (nullable = true)
#  |-- 167: float (nullable = true)
#  |-- 168: float (nullable = true)
#  |-- 169: float (nullable = true)
#  |-- 170: float (nullable = true)
#  |-- 171: float (nullable = true)
#  |-- 172: float (nullable = true)
#  |-- 173: float (nullable = true)
#  |-- 174: float (nullable = true)
#  |-- 175: float (nullable = true)
#  |-- 176: float (nullable = true)
#  |-- 177: float (nullable = true)
#  |-- 178: float (nullable = true)
#  |-- 179: float (nullable = true)
#  |-- 180: float (nullable = true)
#  |-- 181: float (nullable = true)
#  |-- 182: float (nullable = true)
#  |-- 183: float (nullable = true)
#  |-- 184: float (nullable = true)
#  |-- 185: float (nullable = true)
#  |-- 186: float (nullable = true)
#  |-- 187: float (nullable = true)
#  |-- 188: float (nullable = true)
#  |-- 189: float (nullable = true)
#  |-- 190: float (nullable = true)
#  |-- 191: float (nullable = true)
#  |-- 192: float (nullable = true)
#  |-- 193: float (nullable = true)
#  |-- 194: float (nullable = true)
#  |-- 195: float (nullable = true)
#  |-- 196: float (nullable = true)
#  |-- 197: float (nullable = true)
#  |-- 198: float (nullable = true)
#  |-- 199: float (nullable = true)
#  |-- 200: float (nullable = true)
#  |-- 201: float (nullable = true)
#  |-- 202: float (nullable = true)
#  |-- 203: float (nullable = true)
#  |-- 204: float (nullable = true)
#  |-- 205: float (nullable = true)
#  |-- 206: float (nullable = true)
#  |-- 207: float (nullable = true)
#  |-- 208: float (nullable = true)
#  |-- 209: float (nullable = true)
#  |-- 210: float (nullable = true)
#  |-- 211: float (nullable = true)
#  |-- 212: float (nullable = true)
#  |-- 213: float (nullable = true)
#  |-- 214: float (nullable = true)
#  |-- 215: float (nullable = true)
#  |-- 216: float (nullable = true)
#  |-- 217: float (nullable = true)
#  |-- 218: float (nullable = true)
#  |-- 219: float (nullable = true)
#  |-- 220: float (nullable = true)
#  |-- 221: float (nullable = true)
#  |-- 222: float (nullable = true)
#  |-- 223: float (nullable = true)
#  |-- 224: float (nullable = true)
#  |-- 225: float (nullable = true)
#  |-- 226: float (nullable = true)
#  |-- 227: float (nullable = true)
#  |-- 228: float (nullable = true)
#  |-- 229: float (nullable = true)
#  |-- 230: float (nullable = true)
#  |-- 231: float (nullable = true)
#  |-- 232: float (nullable = true)
#  |-- 233: float (nullable = true)
#  |-- 234: float (nullable = true)
#  |-- 235: float (nullable = true)
#  |-- 236: float (nullable = true)
#  |-- 237: float (nullable = true)
#  |-- 238: float (nullable = true)
#  |-- 239: float (nullable = true)
#  |-- 240: float (nullable = true)
#  |-- 241: float (nullable = true)
#  |-- 242: float (nullable = true)
#  |-- 243: float (nullable = true)
#  |-- 244: float (nullable = true)
#  |-- 245: float (nullable = true)
#  |-- 246: float (nullable = true)
#  |-- 247: float (nullable = true)
#  |-- 248: float (nullable = true)
#  |-- 249: float (nullable = true)
#  |-- 250: float (nullable = true)
#  |-- 251: float (nullable = true)
#  |-- 252: float (nullable = true)
#  |-- 253: float (nullable = true)
#  |-- 254: float (nullable = true)
#  |-- 255: float (nullable = true)
#  |-- 256: float (nullable = true)
#  |-- 257: float (nullable = true)
#  |-- 258: float (nullable = true)
#  |-- 259: float (nullable = true)
#  |-- 260: float (nullable = true)
#  |-- 261: float (nullable = true)
#  |-- 262: float (nullable = true)
#  |-- 263: float (nullable = true)
#  |-- 264: float (nullable = true)
#  |-- 265: float (nullable = true)
#  |-- 266: float (nullable = true)
#  |-- 267: float (nullable = true)
#  |-- 268: float (nullable = true)
#  |-- 269: float (nullable = true)
#  |-- 270: float (nullable = true)
#  |-- 271: float (nullable = true)
#  |-- 272: float (nullable = true)
#  |-- 273: float (nullable = true)
#  |-- 274: float (nullable = true)
#  |-- 275: float (nullable = true)
#  |-- 276: float (nullable = true)
#  |-- 277: float (nullable = true)
#  |-- 278: float (nullable = true)
#  |-- 279: float (nullable = true)
#  |-- 280: float (nullable = true)
#  |-- 281: float (nullable = true)
#  |-- 282: float (nullable = true)
#  |-- 283: float (nullable = true)
#  |-- 284: float (nullable = true)
#  |-- 285: float (nullable = true)
#  |-- 286: float (nullable = true)
#  |-- 287: float (nullable = true)
#  |-- 288: float (nullable = true)
#  |-- 289: float (nullable = true)
#  |-- 290: float (nullable = true)
#  |-- 291: float (nullable = true)
#  |-- 292: float (nullable = true)
#  |-- 293: float (nullable = true)
#  |-- 294: float (nullable = true)
#  |-- 295: float (nullable = true)
#  |-- 296: float (nullable = true)
#  |-- 297: float (nullable = true)
#  |-- 298: float (nullable = true)
#  |-- 299: float (nullable = true)
#  |-- 300: float (nullable = true)
#  |-- 301: float (nullable = true)
#  |-- 302: float (nullable = true)
#  |-- 303: float (nullable = true)
#  |-- 304: float (nullable = true)
#  |-- 305: float (nullable = true)
#  |-- 306: float (nullable = true)
#  |-- 307: float (nullable = true)
#  |-- 308: float (nullable = true)
#  |-- 309: float (nullable = true)
#  |-- 310: float (nullable = true)
#  |-- 311: float (nullable = true)
#  |-- 312: float (nullable = true)
#  |-- 313: float (nullable = true)
#  |-- 314: float (nullable = true)
#  |-- 315: float (nullable = true)
#  |-- 316: float (nullable = true)
#  |-- 317: float (nullable = true)
#  |-- 318: float (nullable = true)
#  |-- 319: float (nullable = true)
#  |-- 320: float (nullable = true)
#  |-- 321: float (nullable = true)
#  |-- 322: float (nullable = true)
#  |-- 323: float (nullable = true)
#  |-- 324: float (nullable = true)
#  |-- 325: float (nullable = true)
#  |-- 326: float (nullable = true)
#  |-- 327: float (nullable = true)
#  |-- 328: float (nullable = true)
#  |-- 329: float (nullable = true)
#  |-- 330: float (nullable = true)
#  |-- 331: float (nullable = true)
#  |-- 332: float (nullable = true)
#  |-- 333: float (nullable = true)
#  |-- 334: float (nullable = true)
#  |-- 335: float (nullable = true)
#  |-- 336: float (nullable = true)
#  |-- 337: float (nullable = true)
#  |-- 338: float (nullable = true)
#  |-- 339: float (nullable = true)
#  |-- 340: float (nullable = true)
#  |-- 341: float (nullable = true)
#  |-- 342: float (nullable = true)
#  |-- 343: float (nullable = true)
#  |-- 344: float (nullable = true)
#  |-- 345: float (nullable = true)
#  |-- 346: float (nullable = true)
#  |-- 347: float (nullable = true)
#  |-- 348: float (nullable = true)
#  |-- 349: float (nullable = true)
#  |-- 350: float (nullable = true)
#  |-- 351: float (nullable = true)
#  |-- 352: float (nullable = true)
#  |-- 353: float (nullable = true)
#  |-- 354: float (nullable = true)
#  |-- 355: float (nullable = true)
#  |-- 356: float (nullable = true)
#  |-- 357: float (nullable = true)
#  |-- 358: float (nullable = true)
#  |-- 359: float (nullable = true)
#  |-- 360: float (nullable = true)
#  |-- 361: float (nullable = true)
#  |-- 362: float (nullable = true)
#  |-- 363: float (nullable = true)
#  |-- 364: float (nullable = true)
#  |-- 365: float (nullable = true)
#  |-- 366: float (nullable = true)
#  |-- 367: float (nullable = true)
#  |-- 368: float (nullable = true)
#  |-- 369: float (nullable = true)
#  |-- 370: float (nullable = true)
#  |-- 371: float (nullable = true)
#  |-- 372: float (nullable = true)
#  |-- 373: float (nullable = true)
#  |-- 374: float (nullable = true)
#  |-- 375: float (nullable = true)
#  |-- 376: float (nullable = true)
#  |-- 377: float (nullable = true)
#  |-- 378: float (nullable = true)
#  |-- 379: float (nullable = true)
#  |-- 380: float (nullable = true)
#  |-- 381: float (nullable = true)
#  |-- 382: float (nullable = true)
#  |-- 383: float (nullable = true)
#  |-- 384: float (nullable = true)
#  |-- 385: float (nullable = true)
#  |-- 386: float (nullable = true)
#  |-- 387: float (nullable = true)
#  |-- 388: float (nullable = true)
#  |-- 389: float (nullable = true)
#  |-- 390: float (nullable = true)
#  |-- 391: float (nullable = true)
#  |-- 392: float (nullable = true)
#  |-- 393: float (nullable = true)
#  |-- 394: float (nullable = true)
#  |-- 395: float (nullable = true)
#  |-- 396: float (nullable = true)
#  |-- 397: float (nullable = true)
#  |-- 398: float (nullable = true)
#  |-- 399: float (nullable = true)
#  |-- 400: float (nullable = true)
#  |-- 401: float (nullable = true)
#  |-- 402: float (nullable = true)
#  |-- 403: float (nullable = true)
#  |-- 404: float (nullable = true)
#  |-- 405: float (nullable = true)
#  |-- 406: float (nullable = true)
#  |-- 407: float (nullable = true)
#  |-- 408: float (nullable = true)
#  |-- 409: float (nullable = true)
#  |-- 410: float (nullable = true)
#  |-- 411: float (nullable = true)
#  |-- 412: float (nullable = true)
#  |-- 413: float (nullable = true)
#  |-- 414: float (nullable = true)
#  |-- 415: float (nullable = true)
#  |-- 416: float (nullable = true)
#  |-- 417: float (nullable = true)
#  |-- 418: float (nullable = true)
#  |-- 419: float (nullable = true)
#  |-- 420: float (nullable = true)
#  |-- 421: float (nullable = true)
#  |-- 422: float (nullable = true)
#  |-- 423: float (nullable = true)
#  |-- 424: float (nullable = true)
#  |-- 425: float (nullable = true)
#  |-- 426: float (nullable = true)
#  |-- 427: float (nullable = true)
#  |-- 428: float (nullable = true)
#  |-- 429: float (nullable = true)
#  |-- 430: float (nullable = true)
#  |-- 431: float (nullable = true)
#  |-- 432: float (nullable = true)
#  |-- 433: float (nullable = true)
#  |-- 434: float (nullable = true)
#  |-- 435: float (nullable = true)
#  |-- 436: float (nullable = true)
#  |-- 437: float (nullable = true)
#  |-- 438: float (nullable = true)
#  |-- 439: float (nullable = true)
#  |-- 440: float (nullable = true)
#  |-- 441: float (nullable = true)
#  |-- 442: float (nullable = true)
#  |-- 443: float (nullable = true)
#  |-- 444: float (nullable = true)
#  |-- 445: float (nullable = true)
#  |-- 446: float (nullable = true)
#  |-- 447: float (nullable = true)
#  |-- 448: float (nullable = true)
#  |-- 449: float (nullable = true)
#  |-- 450: float (nullable = true)
#  |-- 451: float (nullable = true)
#  |-- 452: float (nullable = true)
#  |-- 453: float (nullable = true)
#  |-- 454: float (nullable = true)
#  |-- 455: float (nullable = true)
#  |-- 456: float (nullable = true)
#  |-- 457: float (nullable = true)
#  |-- 458: float (nullable = true)
#  |-- 459: float (nullable = true)
#  |-- 460: float (nullable = true)
#  |-- 461: float (nullable = true)
#  |-- 462: float (nullable = true)
#  |-- 463: float (nullable = true)
#  |-- 464: float (nullable = true)
#  |-- 465: float (nullable = true)
#  |-- 466: float (nullable = true)
#  |-- 467: float (nullable = true)
#  |-- 468: float (nullable = true)
#  |-- 469: float (nullable = true)
#  |-- 470: float (nullable = true)
#  |-- 471: float (nullable = true)
#  |-- 472: float (nullable = true)
#  |-- 473: float (nullable = true)
#  |-- 474: float (nullable = true)
#  |-- 475: float (nullable = true)
#  |-- 476: float (nullable = true)
#  |-- 477: float (nullable = true)
#  |-- 478: float (nullable = true)
#  |-- 479: float (nullable = true)
#  |-- 480: float (nullable = true)
#  |-- 481: float (nullable = true)
#  |-- 482: float (nullable = true)
#  |-- 483: float (nullable = true)
#  |-- 484: float (nullable = true)
#  |-- 485: float (nullable = true)
#  |-- 486: float (nullable = true)
#  |-- 487: float (nullable = true)
#  |-- 488: float (nullable = true)
#  |-- 489: float (nullable = true)
#  |-- 490: float (nullable = true)
#  |-- 491: float (nullable = true)
#  |-- 492: float (nullable = true)
#  |-- 493: float (nullable = true)
#  |-- 494: float (nullable = true)
#  |-- 495: float (nullable = true)
#  |-- 496: float (nullable = true)
#  |-- 497: float (nullable = true)
#  |-- 498: float (nullable = true)
#  |-- 499: float (nullable = true)
#  |-- 500: float (nullable = true)
#  |-- 501: float (nullable = true)
#  |-- 502: float (nullable = true)
#  |-- 503: float (nullable = true)
#  |-- 504: float (nullable = true)
#  |-- 505: float (nullable = true)
#  |-- 506: float (nullable = true)
#  |-- 507: float (nullable = true)
#  |-- 508: float (nullable = true)
#  |-- 509: float (nullable = true)
#  |-- 510: float (nullable = true)
#  |-- 511: float (nullable = true)
#  |-- 512: float (nullable = true)

# %%
all_features=df_all_features.toPandas()

# %%
all_features.head()
# Out:
#   product_id product_category brand              price quantity favorite  \
# 0       8304                3     4  77.61599999999999        1        0
# 1       8433                2     2           1150.564        1     1128
# 2       9009                2     2           1372.444        1     1081
# 3       9030                2     2           4849.025        1      981
# 4       9583                1     3            53.5182        1        1
#
#   negative_info  coner_numbers  face_numbers  face_x  ...       503       504  \
# 0             0         2515.0           0.0     0.0  ... -0.543722 -0.765462
# 1             0        24562.0           0.0     0.0  ...  2.081845 -0.353054
# 2             0        10672.0           0.0     0.0  ...  1.350494 -0.765462
# 3             0        24149.0           0.0     0.0  ...  1.153007  0.917282
# 4             0        33272.0           0.0     0.0  ...  0.438044 -0.765462
#
#         505       506       507       508       509       510       511  \
# 0 -0.679552  1.663159  0.574418  0.359700 -0.445884  0.340315 -0.706384
# 1 -0.579630  0.592419 -0.576733  0.879988 -0.733702  2.297908  2.227531
# 2 -0.298230 -0.746695 -0.635949 -0.540052 -0.356770  1.967704 -0.706384
# 3  0.307953 -0.746695  0.178981  1.236456  0.168556 -0.567529 -0.706384
# 4 -0.679552 -0.746695 -0.635949 -0.007310 -0.699182 -0.636476  1.409035
#
#         512
# 0 -0.118440
# 1 -0.578162
# 2  2.291177
# 3  0.167084
# 4 -0.578162
#
# [5 rows x 536 columns]

# %%
all_features.to_csv("test_all_features_noPCA.csv",index=None)
